# %% [markdown]
# # IMDB Review Classification using Word Embeddings(GloVe) #
# ## PROBLEM STATEMENT
# In this project we will classify the IMDB reviews for positive and negative reviews using sentiment analysis or emotion AI.<BR>
#
# ## What is Sentiment Analysis?
# In essence, it is the process of determining the emotional tone behind a series of words, used to gain an understanding of the<br>the attitudes, opinions and emotions expressed within an online mention.<br>
#
# ## What is IMDB?
# IMDb, also known as Internet Movie Database, is an online database of information related to world films, television programs,<br>home videos and video games, and internet streams, including cast, production crew and personnel biographies, plot <br>summaries, trivia, and fan reviews and ratings
#
# ## How to perform Classification on Reviews using Sentiment Analysis?##

# %% [markdown]
# ## Steps involved to perform sentiment analysis on given data set
# ## Step 1: Get some sentiment examples
# IMDB review dataset is loaded<br>
# ## Step 2: Extract features from examples
# Transform each example into a Vectorure vector.<br>
# Here we are using GloVe(Global Vectors) Word Embeddings for Vectorure vectors.
# ## What is GloVe?
# GloVe stands for global vectors for word representation. It is an unsupervised learning algorithm developed by Stanford for generating word embeddings by aggregating global word-word co-occurrence matrix from a corpus.
# <br>
# ## What are Word Embeddings?
# In very simplistic terms, Word Embeddings are the texts converted into numbers and there may be different numerical representations of the same text..
# What word2vec does is, it updates the word vectors of a particular word by the probability of finding the word in the vicinity of the context words(i.e. The words around it).So the words which occur around same context words will have word vectors with much similarity.
# Ex. ‘need’ and ‘required’ generally have the same context words around it and thus making them similar in meaning. So, the word vectors of ‘need’ and ‘required’ will be very much similar.
#
# In this project we will be using a variation of word2vec i.e. GloVe(Global Vectors for Word Representation by Jeffrey Pennington, Richard Socher, and Christopher D. Manning. 2014).
# We will use pre-trained word vectors in the project that is open sourced in the Stanford website.
#
# ## Step 3: Train the parameters
# This is where your model will learn from the data. There are multiple ways of using Vectorures to generate an output, algorithms<br> used in this dataset are Logistic Regression,Naive Bayes, SVM and Decision Trees.<br>
# ## Step 4: Test the model
# After we have trained the parameters to fit the training data, we have to make sure our model generalizes to new data, because <br>it's really easy to overfit. The general way of regularizing the model is to prevent parameters from having extreme values.
# and thus this model uses GridSearchCV model for hyperparameter tuning.
# ## Why GridSearchCV for Tuning?
# GridSearchCV lets you combine an estimator with a grid search preamble to tune hyper-parameters. The method picks the optimal <br>parameter from the grid search and uses it with the estimator selected by the user. GridSearchCV inherits the methods from <br>the classifier, so yes, you can use the .score, .predict, etc.. methods directly through the GridSearchCV interface.
# ## Step 5: Compare the Models and derive Observations

# %% [markdown]
# ### lets follow the steps!###

# %% [markdown]
# import all necessary modules

# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from sklearn.model_selection  import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from gensim.scripts.glove2word2vec import glove2word2vec
from gensim.models import KeyedVectors
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,f1_score
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv("imdb_labelled22.csv")

# %% [markdown]
# ## Data Visualization ##

# %%
df.head()
# Out:
#                                              Reviews  sentiments
# 0  A very, very, very slow-moving, aimless movie ...           0
# 1  Not sure who was more lost - the flat characte...           0
# 2  Attempting artiness with black & white and cle...           0
# 3       Very little music or anything to speak of.             0
# 4  The best scene in the movie was when Gerardo i...           1

# %%
df.describe(include='all')
# Out:
#                                  Reviews  sentiments
# count                                998  998.000000
# unique                               996         NaN
# top     Definitely worth checking out.           NaN
# freq                                   2         NaN
# mean                                 NaN    0.498998
# std                                  NaN    0.500250
# min                                  NaN    0.000000
# 25%                                  NaN    0.000000
# 50%                                  NaN    0.000000
# 75%                                  NaN    1.000000
# max                                  NaN    1.000000

# %%
df.shape
# Out:
# (998, 2)

# %% [markdown]
# ### check for any missing value ###

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Let's visualize data###
# ## EDA##

# %%
df['sentiments'].hist(figsize=(10,10))

# %% [markdown]
# Negative reviews are slightly more than positive reviews.<br>
# which shows that people are generally not satisfied.<br>

# %% [markdown]
# ### lets find out high frequecy of negative and positive words###

# %%
reviews = df.Reviews.str.cat(sep=' ')
                                         #function to split text into word
tokens = word_tokenize(reviews)
vocabulary = set(tokens)                  #removing duplicates
print(len(vocabulary))
frequency_dist = nltk.FreqDist(vocabulary)
sorted(frequency_dist,key=frequency_dist.__getitem__, reverse=True)[0:50]
# Out:
# 3419
# ['twice',
#  'trysts',
#  'ordeal',
#  'super',
#  'editing',
#  'recent',
#  'nonetheless',
#  'twist',
#  'Bergen',
#  'interacting',
#  'forced',
#  'class',
#  'someone',
#  'hockey',
#  'trilogy',
#  'had',
#  'shed',
#  '54',
#  'renowned',
#  'ridiculous',
#  'back',
#  'lower',
#  'Ackerman',
#  'grace',
#  'numbers',
#  'watching',
#  'forgettable',
#  'often',
#  'feel-good',
#  '90',
#  'schizophrenic',
#  'treachery',
#  'ho',
#  'continually',
#  'acting-wise',
#  'Ponyo',
#  'efforts',
#  'DonLevy',
#  'heads',
#  'credit',
#  'climax',
#  'poet',
#  'meld',
#  'where',
#  'MOVIE',
#  'parents',
#  'actions',
#  'art',
#  'goes',
#  'cruel']

# %%
stop_words = set(stopwords.words('english')) #stopwords are  very commomly used words(for eg. is,am,..etc.)
tokens = [w for w in vocabulary if w not in stop_words]
tokens
# Out:
# ['twice',
#  'trysts',
#  'ordeal',
#  'super',
#  'editing',
#  'recent',
#  'nonetheless',
#  'twist',
#  'Bergen',
#  'interacting',
#  'forced',
#  'class',
#  'someone',
#  'hockey',
#  'trilogy',
#  'shed',
#  '54',
#  'renowned',
#  'ridiculous',
#  'back',
#  'lower',
#  'Ackerman',
#  'grace',
#  'numbers',
#  'watching',
#  'forgettable',
#  'often',
#  'feel-good',
#  '90',
#  'schizophrenic',
#  'treachery',
#  'ho',
#  'continually',
#  'acting-wise',
#  'Ponyo',
#  'efforts',
#  'DonLevy',
#  'heads',
#  'credit',
#  'climax',
#  'poet',
#  'meld',
#  'MOVIE',
#  'parents',
#  'actions',
#  'art',
#  'goes',
#  'cruel',
#  'Brian',
#  'delights',
#  'Coppola',
#  'adorable',
#  'Sundays',
#  'Steve',
#  'male',
#  'weaker',
#  'portrayed',
#  'Plmer',
#  'coastal',
#  'court',
#  'ca',
#  'decent',
#  'jerky',
#  'bipolarity',
#  'hell',
#  'Gas',
#  'unbelievable',
#  'miss',
#  'obvious',
#  'dreams',
#  'romantic',
#  'Regardless',
#  'single',
#  'Peter',
#  'paint',
#  'dialogs',
#  'dollars',
#  'paced',
#  'sloppy',
#  'astronaut',
#  'clients',
#  'require',
#  'stinks',
#  'alike',
#  'Horse',
#  'contained',
#  'addition',
#  'Constantine',
#  'rejection',
#  'Blake',
#  'three',
#  'antithesis',
#  'oh',
#  'baaaaaad',
#  'Tony',
#  'pap',
#  'comfortable',
#  'And',
#  'ten',
#  'Sean',
#  'old-fashioned',
#  'faux',
#  'noir',
#  'understanding',
#  'Look',
#  'refreshing',
#  'akin',
#  'thinking',
#  'Speed',
#  'Judith',
#  'succeeds',
#  'site',
#  'living/working',
#  'intelligence',
#  'tears',
#  'f/x',
#  'One',
#  'SPOILER',
#  'McHattie',
#  'Florida',
#  'remaining',
#  'crayon/pencil',
#  'different',
#  'average',
#  'Fausa',
#  'Haggis',
#  'recover',
#  'Nicola',
#  'Im',
#  'draft',
#  'underlying',
#  'be-all',
#  'IS',
#  'understated',
#  'repertory',
#  '8',
#  'thoughts',
#  'THERE',
#  'Mansonites',
#  'Body',
#  'Dickens',
#  'take',
#  'Bennett',
#  'comprehensible',
#  'spiffy',
#  'behold',
#  'holding',
#  'acclaimed',
#  'accurate',
#  'stocking',
#  'blue/green-screen',
#  'intelligent',
#  'built',
#  'hip',
#  'graphics',
#  '8.15pm',
#  'brat',
#  'future',
#  'Instead',
#  'greatest',
#  'indication',
#  'makers',
#  'Ebola',
#  'half',
#  'impression',
#  'trinity',
#  'For',
#  'Hilarious',
#  'footage',
#  'cowardice',
#  'poetry',
#  'Riz',
#  'Snow',
#  'Awful',
#  'Ebay',
#  'sites',
#  'casting',
#  'underbite',
#  'Ishioka',
#  'together',
#  'great',
#  'shined',
#  'babysitting',
#  'WB',
#  'following',
#  'SO',
#  'Feeling',
#  'sum',
#  'discovering',
#  'chance',
#  'resume',
#  'foolish',
#  'famed',
#  'confidence',
#  'instruments',
#  'moral',
#  'Hayworth',
#  'damn',
#  'experiences',
#  'friendship',
#  'managed',
#  'screenplay',
#  'non-researched',
#  'self',
#  'perfect',
#  'Girolamo',
#  'Darren',
#  'Connery',
#  'Jim',
#  'audio',
#  'confirm',
#  'sequences',
#  'endlessly',
#  'Hence',
#  'well-balanced',
#  'Jerry',
#  'Things',
#  'miserable',
#  'stereotypically',
#  'late',
#  'might',
#  'strange',
#  'Punishment',
#  'horrified',
#  'fantastic',
#  'acting',
#  'NO',
#  'Buy',
#  'whenever',
#  'mistakes',
#  'threshold',
#  'na',
#  'fingernails',
#  'Tale',
#  'related',
#  'generates',
#  'Ue',
#  'controversy',
#  'Giovanni',
#  'Harris',
#  'Rita',
#  'instant',
#  'example',
#  'power',
#  'Z',
#  'opening',
#  'lid',
#  'debated',
#  'evaluate',
#  'Play',
#  'journey',
#  'Jean',
#  'mexican',
#  'I',
#  'If',
#  'peculiarity',
#  'exciting',
#  'towards',
#  'type',
#  'exquisite',
#  'looked',
#  'makes',
#  'intoning',
#  'range',
#  "'re",
#  'warmth',
#  'n',
#  'humorous',
#  'voyage',
#  'Christopher',
#  'From',
#  'premise',
#  'viewing',
#  'mean',
#  'psychological',
#  'mainly',
#  'surf',
#  'knocked',
#  'pair',
#  'Some',
#  'marbles',
#  'terror',
#  'begin',
#  'cross',
#  'finished',
#  'value',
#  'loads',
#  'Hugo',
#  'ed',
#  'hes',
#  'PLOT',
#  'Sci-fi',
#  'imaginable',
#  'really',
#  'identifies',
#  'hands',
#  'disbelief',
#  'General',
#  'Armageddon',
#  'lust',
#  '``',
#  'Candace',
#  'failed',
#  'Academy',
#  'treatments',
#  'Puppet',
#  'purity',
#  "'film",
#  'narrative',
#  'sat',
#  'repeated',
#  'part',
#  'free',
#  'kinda',
#  'talents',
#  'fishnet',
#  '70000',
#  'title',
#  'Sandra',
#  'talk',
#  'smoothly',
#  'delivered',
#  'always',
#  'lines',
#  'Mickey',
#  'sci',
#  'How',
#  'length',
#  'backed',
#  'Cast',
#  '.',
#  'rips',
#  'boss',
#  'Howell',
#  'tying',
#  'hour',
#  'continue',
#  'courtroom',
#  'Anthony',
#  'depends',
#  'excellent',
#  'exceptional',
#  '95',
#  'God',
#  'Slideshow',
#  'store',
#  'foreign',
#  'brilliance',
#  'hours',
#  'marriage',
#  'may',
#  'SEE',
#  'provided',
#  'Thunderbirds',
#  'tries',
#  'versus',
#  'fx',
#  'Tom',
#  'past',
#  'choices',
#  'universe',
#  'memories',
#  'volcano',
#  'brainsucking',
#  'air',
#  'flicks',
#  'below-par',
#  'screen..James',
#  'everybody',
#  'war',
#  'Howe',
#  'barely',
#  'monolog',
#  'top',
#  'talent',
#  'continuously',
#  'Foxx',
#  'Groove',
#  'twirling',
#  'looks',
#  'oriented',
#  'acted',
#  'i.e',
#  'low-budget',
#  'insomniacs',
#  'either',
#  'Lewis',
#  'Perabo',
#  'far',
#  'escalating',
#  'pictures',
#  'reporter',
#  'Vivian',
#  'shot',
#  'producer',
#  'disappointing',
#  'handle',
#  'Brilliant',
#  'Horror',
#  'enjoyed',
#  'voice',
#  'CLASSIC',
#  'received',
#  'flat',
#  'naked.Billy',
#  'Funny',
#  'fisted',
#  'M',
#  'unforgettable',
#  'fails',
#  'reading',
#  'bat',
#  'menacing',
#  'control',
#  'quiet',
#  'blah',
#  'dark',
#  'Aside',
#  'raver',
#  'question',
#  'He',
#  'warts',
#  'Kathy',
#  'singing',
#  'hand-drawn',
#  'sinking',
#  'number',
#  'swamp',
#  'AND',
#  'Americans',
#  'atrocious',
#  'seem',
#  'Frances',
#  'things',
#  'disturbing',
#  'switched',
#  'Southern',
#  'IMDB',
#  'scripts',
#  'win',
#  'thought-provoking',
#  'While',
#  'pure',
#  'nun',
#  '4',
#  'local',
#  'Director',
#  'easy',
#  'fun',
#  'contributory',
#  'Excellent',
#  'sibling',
#  'Cotton',
#  'apt',
#  'pointless',
#  'blood',
#  'delivers',
#  'Rubin',
#  'forces',
#  'see',
#  'lilt',
#  'avoided',
#  'video',
#  'Smith',
#  'old',
#  'jobs',
#  'Aailiyah',
#  'WHAT',
#  'spoiled',
#  'carry',
#  'Pitch',
#  'small',
#  'coach',
#  'Helms',
#  'convincing',
#  'film',
#  'pitiful',
#  'It',
#  'complete',
#  'insane',
#  'one',
#  'earlier',
#  'Show',
#  'sequence',
#  'gently',
#  'show.These',
#  'Babie',
#  'soundtrack',
#  'exteriors',
#  'abroad',
#  'Allison',
#  'weight',
#  'jet',
#  'self-discovery',
#  'veteran',
#  'Rating',
#  'Seuss',
#  'coherent',
#  'bother',
#  'freedom',
#  'classic',
#  'whiny',
#  'Parker',
#  'character',
#  'shallow',
#  'edge',
#  'basic',
#  'idea',
#  'shows',
#  'whatever',
#  'sit',
#  'Negulesco',
#  'Macbeth',
#  'crap',
#  'girlfriend/boyfriend',
#  'material',
#  'borrowed',
#  '.stylized',
#  'Being',
#  'VERY',
#  'voice-overs',
#  'shenanigans',
#  'Hayao',
#  'But',
#  'young',
#  'Canada',
#  'California',
#  'fact',
#  'consequences',
#  'deserving',
#  'bakery',
#  'Wayne',
#  '1998',
#  'Work',
#  'last',
#  'Jonah',
#  'crocdodile',
#  'redeemed',
#  'masculinity',
#  'prone',
#  'supposedly',
#  'admitted',
#  'Aurvåg',
#  'full',
#  'imaginative',
#  'pedestal',
#  'savor',
#  'effort',
#  'SETS',
#  'readers',
#  'McLaglen',
#  'Chodorov',
#  'bad',
#  'Ann',
#  'dependant',
#  'ROAD',
#  'almost',
#  'rocks',
#  'direction',
#  'Fire',
#  'told',
#  'series',
#  'phenomenal',
#  'touching',
#  'suck',
#  'cat',
#  'strokes',
#  'wont',
#  'spew',
#  'possible',
#  'suited',
#  'write',
#  'collective',
#  'timers',
#  'You',
#  'definitely',
#  'contrast',
#  'can-do',
#  'Boyle',
#  'superficial',
#  'terrible',
#  'note',
#  'sappiest',
#  "'Ive",
#  'B',
#  'unethical',
#  'wasting',
#  'Light',
#  'LaSelva',
#  'including',
#  'Regrettably',
#  'reason',
#  'heroine',
#  'Plus',
#  'indie',
#  'Falwell',
#  'Angeles',
#  'animated',
#  'spoilers',
#  'existential',
#  'well',
#  'frankly',
#  'higher',
#  'heaven',
#  'knew',
#  'right',
#  'Monica',
#  'surely',
#  'relations',
#  'Shirley',
#  'Ventura',
#  'century',
#  'Otherwise',
#  'Their',
#  'look',
#  'FX',
#  'tremendous',
#  'Avoid',
#  'Daughter',
#  'Lassie',
#  'head-over-heels',
#  'running',
#  'In',
#  'self-sacrifice',
#  'bible',
#  'monster',
#  'nuns',
#  'Snider',
#  'predictable',
#  'villains',
#  'doctor',
#  'unmoving',
#  'Charlie',
#  'uninteresting',
#  'characters',
#  'ALL',
#  'highly',
#  'Knightley',
#  'review',
#  'shortlist',
#  'unmatched',
#  'struggle',
#  'serious',
#  'Havilland',
#  'BAD',
#  'emptiness',
#  'realize',
#  'release',
#  'bond',
#  'reviews',
#  'hill',
#  'undertone',
#  'Park',
#  'Later',
#  'mention',
#  "'ll",
#  'middle-aged',
#  'side',
#  'author',
#  'powerhouse',
#  'cheekbones',
#  'night',
#  'less',
#  'Lance',
#  'outward',
#  'considering',
#  'Despite',
#  'touch',
#  'Was',
#  'convey',
#  'interest',
#  'Pulling',
#  'stealing',
#  'allow',
#  'senses',
#  'logic',
#  'Townsend',
#  'function',
#  'Okay',
#  'ability',
#  'couple',
#  'filmed',
#  'deserves',
#  'honestly',
#  "so-bad-it's-memorable",
#  'rent',
#  'Nine',
#  'admiration',
#  'scary',
#  'Considering',
#  'fest',
#  'Bad',
#  'sing',
#  'Summary',
#  'Balls',
#  'hide',
#  'particular',
#  'Hackneyed',
#  'eyes',
#  'critic',
#  'Impact',
#  'latest',
#  'bonus',
#  'applauded',
#  '1973',
#  'directors',
#  '!',
#  'feet',
#  'tsunami',
#  'selections',
#  'generic',
#  'regret',
#  'wholesome',
#  'Waste',
#  'wide',
#  'apart',
#  'Loewenhielm',
#  'whole',
#  'deserved',
#  'William',
#  'comments',
#  'camp',
#  'mollusk',
#  'afternoon',
#  'Sorrentino',
#  'cute',
#  'There',
#  'intentions',
#  'directed',
#  'Special',
#  'etc',
#  'aesthetically',
#  'desert',
#  'zombie-students',
#  'naughty',
#  '20th',
#  'ass',
#  'amaze',
#  'superb',
#  'taken',
#  'choice',
#  'Started',
#  'attractive',
#  'believed',
#  'expectations',
#  'collect',
#  'Tonight',
#  'another',
#  'cardboard',
#  'She',
#  'certainly',
#  '.an',
#  'cover',
#  'latifa',
#  'circumstances',
#  'interim',
#  'candle',
#  'skip',
#  'Kevin',
#  'Shakespears',
#  'convince',
#  'horrendous',
#  'TV',
#  'team',
#  'features',
#  'towers',
#  "'m",
#  'screenwriter',
#  'colours',
#  'taking',
#  'buildings',
#  'thing',
#  'rise',
#  'outside',
#  'They',
#  'imagine',
#  'stratus',
#  'incendiary',
#  'entertained',
#  'nice',
#  'explanation',
#  'actresses',
#  'Word',
#  'questioning',
#  'Season',
#  'Bop',
#  'semi',
#  'falls',
#  'uplifting',
#  'phony',
#  'crackles',
#  'offer',
#  'truly',
#  'Custer',
#  'system',
#  'Water',
#  'upper',
#  'Conclusion',
#  'lieutenant',
#  'call',
#  'dislike',
#  'crew',
#  'bland',
#  'appears',
#  'realised',
#  'eating',
#  'gung',
#  'would-be',
#  'overall',
#  'sack',
#  'pull',
#  'comment',
#  'performances',
#  'Enough',
#  'age',
#  'thriller',
#  'la',
#  'Ed',
#  'Then',
#  'THINKING',
#  'score',
#  'Traffic',
#  'Girl',
#  'Up',
#  'unrealistic',
#  'stunning',
#  'Never',
#  'wrap',
#  'Jaclyn',
#  'state-of-the-art',
#  'close-ups',
#  'errors',
#  'bore',
#  'huge',
#  'poler',
#  'conclusion',
#  'killer',
#  'self-indulgent',
#  'Phantasm',
#  'poised',
#  'sells',
#  'continuation',
#  'fifties',
#  'relate',
#  'disparate',
#  'slimy',
#  'sisters',
#  'sure',
#  'unremarkable',
#  'Buffet',
#  'desperately',
#  'excruciatingly',
#  'Doctor',
#  'trash',
#  'Channel',
#  'classical',
#  'whether',
#  'made',
#  'whatsoever',
#  'Seriously',
#  'never',
#  'Mother',
#  'era',
#  'drag',
#  'bully',
#  'portrayals',
#  'touches',
#  'earth',
#  'Had',
#  'ranks',
#  'realized',
#  'released',
#  'Go',
#  'relaxing',
#  'Taelons',
#  'talented',
#  'amateurish',
#  'expected',
#  'appropriate',
#  'rating',
#  'difference',
#  '1-10',
#  'younger',
#  'unnecessary',
#  'joy',
#  'subject',
#  'must-have',
#  'keeps',
#  'expression',
#  'worthy',
#  'teen',
#  'except',
#  'subversive',
#  'rendition',
#  'conflict',
#  'impressed',
#  'film-maker',
#  'tacky',
#  'depending',
#  'Her',
#  'keep',
#  'See',
#  'sometimes',
#  'Studio',
#  'worst',
#  'heart',
#  'looking',
#  'watchable',
#  'shell',
#  'rubbish',
#  'believable',
#  'Affleck',
#  'whites',
#  'Casting',
#  'typical',
#  'terminology',
#  'falling',
#  'torture',
#  'Imperial',
#  'sick',
#  'A+',
#  'Luv',
#  'notable',
#  'UPA',
#  'freshness',
#  'curtain',
#  'setting',
#  'trumpeter',
#  'containing',
#  'TARDIS',
#  'minutes',
#  'Sydney',
#  'amusing',
#  'smile',
#  'tract',
#  'began',
#  'provokes',
#  'translating',
#  'effective',
#  'sitcoms',
#  'WRITTEN',
#  'happen',
#  'Bertolucci',
#  'known',
#  'public',
#  'Editing',
#  '0/10',
#  'Sam',
#  'fish',
#  'jealousy',
#  'repeating',
#  'innocence',
#  'commercial',
#  'fame',
#  'day',
#  'actually',
#  'dialog',
#  'says',
#  'soon',
#  'The',
#  'living',
#  'outlandish',
#  'ends',
#  'Generally',
#  'cute.But',
#  'paid',
#  'loose',
#  'avoid',
#  'bonuses',
#  'aspects',
#  'enjoyable',
#  'accolades',
#  'ole',
#  'underacting',
#  ';',
#  'horror/suspense',
#  'Ironically',
#  'unrestrained',
#  'falsely',
#  'salesman',
#  'incredible',
#  'accessible',
#  'Shatner',
#  'nerves',
#  'mini-series',
#  'facing',
#  'pointillistic',
#  'supernatural',
#  'set',
#  'it.Buy',
#  'ground-breaking',
#  'soap',
#  'Edward',
#  'wants',
#  'give',
#  'seemed',
#  'American',
#  'doubt',
#  'None',
#  'feel',
#  ...]

# %%
def preprocess(raw_text, flag):
    letters_only = re.sub("[^a-zA-Z]", " ",raw_text)
    
    # change sentence to lower case
    letters_only = letters_only.lower()

    # tokenize into words
    words = letters_only.split()
    
    # remove stop words                
    words = [w for w in words if not w in stopwords.words("english")]
    
    
    if flag == 1:
        return(" ".join(words))
    else:
        return(len(words))

# %%
df['clean_text']=df['Reviews'].apply(lambda x: preprocess(x, flag=1)) #cleaning data
df['Text_length']=df['Reviews'].apply(lambda x: preprocess(x, flag=2)) # finding minimum length

# %%
Neg=df[df['sentiments']==0]
Neg_Token=list()
for i in Neg['clean_text']:
    if 'movie' in i or 'film' in i:
        pass
    else:
        Neg_Token=Neg_Token+i.split(" ")
Neg_Corpus=" ".join(Neg_Token)
wordcloud=WordCloud(height=800,width=600,background_color='white').generate(Neg_Corpus)

plt.figure(figsize=(15,10))
plt.title("WordCloud For Negative Reviews \n")
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# ### Highly used words in Negative reviews: ###
#  1.bad<br>
#  2.acting<br>
#  3.even<br>
#  4.one<br>
#  5.plot<br>
#  6.script<br>
#  7.character

# %%
Pos=df[df['sentiments']==1]
Pos_Token=list()
for i in Pos['clean_text']:
    if 'movie' in i or 'film' in i:
        pass
    else:
        Pos_Token=Pos_Token+i.split(" ") #converting string into list
Pos_Corpus=" ".join(Pos_Token)
wordcloud=WordCloud(height=800,width=800,background_color='white').generate(Pos_Corpus)

plt.figure(figsize=(15,10))
plt.title("WordCloud For Positive Reviews \n")
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# ### Highly used words in Positive reviews: ###
#  1.good<br>
#  2.great<br>
#  3.really<br>
#  4.performance<br>
#  5.character<br>
#  6.wonderful<br>
#  7.funny

# %% [markdown]
# ## GloVe##

# %%
glove2word2vec(glove_input_file='glove.6B.50d.txt',word2vec_output_file="Vect.txt")
model=KeyedVectors.load_word2vec_format("Vect.txt")

# %% [markdown]
# Now let's Make 2 DataFrames, Normalised Sentence Vectors and Not-Normalised Sentence Vectors.<br>
# <br>
# ##### Not-Normalised Sentence Vectors=Sentence vector(S)[50-dim]= (word_vector(w1)+word_vector(w2)+word_vector(w3))
#
# ##### Normalised Sentence Vectors=Sentence vector normalized(S)[50-dim]= (word_vector(w1)+word_vector(w2)+word_vector(w3))/ (number of words)

# %% [markdown]
# ## summing vectors for text-reviews##
# ### Not-Normalized###

# %%
Def_List=[0]*50   #for those words whose vectors are not present in glove are assigned 0 
def Get_Sum(x,Def_List,ret_val):
    vec=Def_List
    for i in x:
        try:
            vec=np.add(vec,model[i])
        except:
            vec=np.add(vec,Def_List)
            continue
    return vec[ret_val]
Not_Norm=df
for i in range(50):
    Not_Norm['Vector'+str(i)]=Not_Norm['clean_text'].apply(Get_Sum,args=[Def_List,i])
Not_Norm
# Out:
#                                                Reviews  sentiments  \
# 0    A very, very, very slow-moving, aimless movie ...           0
# 1    Not sure who was more lost - the flat characte...           0
# 2    Attempting artiness with black & white and cle...           0
# 3         Very little music or anything to speak of.             0
# 4    The best scene in the movie was when Gerardo i...           1
# 5    The rest of the movie lacks art, charm, meanin...           0
# 6                                  Wasted two hours.             0
# 7    Saw the movie today and thought it was a good ...           1
# 8                                 A bit predictable.             0
# 9    Loved the casting of Jimmy Buffet as the scien...           1
# 10                And those baby owls were adorable.             1
# 11   The movie showed a lot of Florida at it's best...           1
# 12   The Songs Were The Best And The Muppets Were S...           1
# 13                                   It Was So Cool.             1
# 14   This is a very "right on case" movie that deli...           1
# 15   It had some average acting from the main perso...           0
# 16   This review is long overdue, since I consider ...           1
# 17   I'll put this gem up against any movie in term...           1
# 18   It's practically perfect in all of them  a tr...           1
# 19    The structure of this film is easily the most...           1
# 20   I can think of no other film where something v...           1
# 21   In other words, the content level of this film...           1
# 22   How can anyone in their right mind ask for any...           1
# 23   It's quite simply the highest, most superlativ...           1
# 24   Yes, this film does require a rather significa...           1
# 25       This short film certainly pulls no punches.             0
# 26   Graphics is far from the best part of the game.             0
# 27   This is the number one best TH game in the ser...           1
# 28                          It deserves strong love.             1
# 29                             It is an insane game.             1
# ..                                                 ...         ...
# 968  Enough can not be said of the remarkable anima...           1
# 969  The art style has the appearance of crayon/pen...           1
# 970  If you act in such a film, you should be glad ...           0
# 971  This one wants to surf on the small wave of sp...           0
# 972  If you haven't choked in your own vomit by the...           0
# 973  Still, it makes up for all of this with a supe...           1
# 974  Just consider the excellent story, solid actin...           1
# 975  Instead, we got a bore fest about a whiny, spo...           0
# 976  Then I watched it again two Sundays ago (March...           1
# 977       It is a very well acted and done TV Movie.             1
# 978  Judith Light is one of my favorite actresses a...           1
#
# [998 rows x 54 columns]

# %% [markdown]
# ### Normalized ###

# %%
Def_List=[0]*50
def Get_Sum(x,Def_List,ret_val):
    vec=Def_List
    for i in x:
        try:
            vec=np.add(vec,model[i])
        except:
            vec=np.add(vec,Def_List)
            continue
    vec=np.divide(vec,len(vec))
    return vec[ret_val]

Norm=df
for i in range(50):
    Norm['Vector'+str(i)]=Not_Norm['clean_text'].apply(Get_Sum,args=[Def_List,i])
Norm
# Out:
#                                                Reviews  sentiments  \
# 0    A very, very, very slow-moving, aimless movie ...           0
# 1    Not sure who was more lost - the flat characte...           0
# 2    Attempting artiness with black & white and cle...           0
# 3         Very little music or anything to speak of.             0
# 4    The best scene in the movie was when Gerardo i...           1
# 5    The rest of the movie lacks art, charm, meanin...           0
# 6                                  Wasted two hours.             0
# 7    Saw the movie today and thought it was a good ...           1
# 8                                 A bit predictable.             0
# 9    Loved the casting of Jimmy Buffet as the scien...           1
# 10                And those baby owls were adorable.             1
# 11   The movie showed a lot of Florida at it's best...           1
# 12   The Songs Were The Best And The Muppets Were S...           1
# 13                                   It Was So Cool.             1
# 14   This is a very "right on case" movie that deli...           1
# 15   It had some average acting from the main perso...           0
# 16   This review is long overdue, since I consider ...           1
# 17   I'll put this gem up against any movie in term...           1
# 18   It's practically perfect in all of them  a tr...           1
# 19    The structure of this film is easily the most...           1
# 20   I can think of no other film where something v...           1
# 21   In other words, the content level of this film...           1
# 22   How can anyone in their right mind ask for any...           1
# 23   It's quite simply the highest, most superlativ...           1
# 24   Yes, this film does require a rather significa...           1
# 25       This short film certainly pulls no punches.             0
# 26   Graphics is far from the best part of the game.             0
# 27   This is the number one best TH game in the ser...           1
# 28                          It deserves strong love.             1
# 29                             It is an insane game.             1
# ..                                                 ...         ...
# 968  Enough can not be said of the remarkable anima...           1
# 969  The art style has the appearance of crayon/pen...           1
# 970  If you act in such a film, you should be glad ...           0
# 971  This one wants to surf on the small wave of sp...           0
# 972  If you haven't choked in your own vomit by the...           0
# 973  Still, it makes up for all of this with a supe...           1
# 974  Just consider the excellent story, solid actin...           1
# 975  Instead, we got a bore fest about a whiny, spo...           0
# 976  Then I watched it again two Sundays ago (March...           1
# 977       It is a very well acted and done TV Movie.             1
# 978  Judith Light is one of my favorite actresses a...           1
# 979                I keep watching it over and over.             1
# 980                 It's a sad movie, but very good.             1
# 981  If you have not seen this movie, I definitely ...           1
# 982           She is as lovely as usual, this cutie!             1
# 983  Still it's quite interesting and entertaining ...           1
# 984                    ;) Recommend with confidence!             1
# 985  This movie is well-balanced with comedy and dr...           1
# 986  It was a riot to see Hugo Weaving play a sex-o...           1
# 987  :) Anyway, the plot flowed smoothly and the ma...           1
# 988  The opening sequence of this gem is a classic,...           1
# 989             Fans of the genre will be in heaven.             1
# 990                Lange had become a great actress.             1
# 991                It looked like a wonderful story.             1
# 992            I never walked out of a movie faster.             0
# 993  I just got bored watching Jessice Lange take h...           0
# 994  Unfortunately, any virtue in this film's produ...           0
# 995                   In a word, it is embarrassing.             0
# 996                               Exceptionally bad!             0
# 997  All in all its an insult to one's intelligence...           0
#
#                                             clean_text  Text_length   Vector0  \
# 0    slow moving aimless movie distressed drifting ...            8 -0.087996
# 1    sure lost flat characters audience nearly half...            8 -0.073151
# 2    attempting artiness black white clever camera ...           19 -0.119280
# 3                          little music anything speak            4 -0.043979
# 4    best scene movie gerardo trying find song keep...           10 -0.042775
# 5    rest movie lacks art charm meaning emptiness w...           10 -0.099447
# 6                                     wasted two hours            3 -0.058468
# 7    saw movie today thought good effort good messa...            9 -0.085904
# 8                                      bit predictable            2 -0.016884
# 9           loved casting jimmy buffet science teacher            6 -0.059822
# 10                                  baby owls adorable            3 -0.027271
# 11   movie showed lot florida best made look appealing            8 -0.037519
# 12                        songs best muppets hilarious            4 -0.063568
# 13                                                cool            1 -0.015787
# 14   right case movie delivers everything almost ri...            8 -0.036507
# 15   average acting main person low budget clearly see            8 -0.028217
# 16   review long overdue since consider tale two si...           13 -0.022905
# 17   put gem movie terms screenplay cinematography ...           14 -0.211564
# 18   practically perfect true masterpiece sea faux ...            7 -0.047414
# 19   structure film easily tightly constructed hist...            7 -0.143133
# 20   think film something vitally important occurs ...            8 -0.128355
# 21   words content level film enough easily fill do...            9 -0.100152
# 22                anyone right mind ask anything movie            6 -0.036391
# 23   quite simply highest superlative form cinema i...            7 -0.072954
# 24   yes film require rather significant amount puz...           14 -0.181399
# 25                  short film certainly pulls punches            5 -0.108296
# 26                         graphics far best part game            5 -0.072601
# 27                      number one best th game series            6 -0.005916
# 28                                deserves strong love            3  0.015365
# 29                                         insane game            2  0.010071
# ..                                                 ...          ...       ...
# 968              enough said remarkable animation film            5 -0.045414
# 969  art style appearance crayon pencil drawings wo...            9 -0.213122
# 970  act film glad gonna drift away earth far possible            9 -0.126704
# 971  one wants surf small wave space movies deep im...           13 -0.054004
# 972  choked vomit end cheap drama worthless dialogu...           12 -0.067626
# 973  still makes super ending depicts great sea ves...           11 -0.047877
# 974  consider excellent story solid acting look fil...            9 -0.050003
# 975  instead got bore fest whiny spoiled brat babys...            8 -0.091575
# 976  watched two sundays ago march th began really ...           13 -0.095053
# 977                           well acted done tv movie            5  0.007142
# 978  judith light one favorite actresses think supe...            9 -0.110268
# 979                                      keep watching            2 -0.024435
# 980                                     sad movie good            3  0.005817
# 981                    seen movie definitely recommend            4  0.023345
# 982                                 lovely usual cutie            3 -0.007171
# 983        still quite interesting entertaining follow            5 -0.086647
# 984                               recommend confidence            2 -0.026869
# 985  movie well balanced comedy drama thoroughly en...            7 -0.031219
# 986  riot see hugo weaving play sex obsessed gay re...           19 -0.062243
# 987  anyway plot flowed smoothly male bonding scene...            8 -0.104379
# 988  opening sequence gem classic cat n mouse games...           11 -0.132360
# 989                                  fans genre heaven            3  0.015580
# 990                         lange become great actress            4 -0.011630
# 991                        looked like wonderful story            4 -0.038440
# 992                          never walked movie faster            4  0.010327
# 993      got bored watching jessice lange take clothes            7 -0.051920
# 994  unfortunately virtue film production work lost...            8 -0.194120
# 995                                  word embarrassing            2 -0.052575
# 996                                  exceptionally bad            2  0.009685
# 997           insult one intelligence huge waste money            6 -0.020440
# 991  0.053610 -0.124596 -0.070272 -0.071848  0.149185  0.090031 -0.184852
# 992  0.096795 -0.061415 -0.039729 -0.036831  0.199927  0.105738 -0.174490
# 993  0.055373 -0.146240 -0.019160 -0.000164  0.261656  0.126822 -0.312993
# 994  0.120174 -0.318329 -0.012027 -0.092652  0.366026  0.226973 -0.484611
# 995  0.083625 -0.079769 -0.019026 -0.051420  0.154874  0.059226 -0.137851
# 996  0.019878 -0.056256 -0.013403 -0.052865  0.095600  0.065222 -0.125074
# 997 -0.023901 -0.141921 -0.024341 -0.071144  0.149258  0.129433 -0.300682
#
#      Vector48  Vector49
# 0    0.277105  0.895688
# 1    0.289421  0.956532
# 2    0.904602  2.023073
# 3    0.164934  0.384038
# 4    0.311853  1.167877
# 5    0.341105  0.887120
# 6    0.118751  0.281004
# 7    0.359266  0.936051
# 8    0.089170  0.285991
# 9    0.223956  0.686930
# 10   0.197605  0.311292
# 11   0.386223  0.773292
# 12   0.234515  0.379075
# 13   0.072485  0.067758
# 14   0.253842  0.921606
# 15   0.329926  0.825627
# 16   0.442054  1.426860
# 17   0.526998  1.759799
# 18   0.309071  0.959822
# 19   0.243030  1.013531
# 20   0.276200  0.893454
# 21   0.365651  0.931153
# 22   0.178988  0.601860
# 23   0.296043  0.804452
# 24   0.474274  1.752840
# 25   0.231735  0.556201
# 26   0.121001  0.446823
# 27   0.183703  0.447529
# 28   0.161608  0.371053
# 29   0.067475  0.147207
# ..        ...       ...
# 968  0.159399  0.587031
# 969  0.457896  1.455368
# 970  0.229318  0.852263
# 971  0.550252  1.268123
# 972  0.417642  1.230854
# 973  0.381628  1.081345
# 974  0.399440  1.127893
# 975  0.344788  0.919527
# 976  0.445742  1.294215
# 977  0.171179  0.350845
# 978  0.307255  0.932239
# 979  0.099530  0.227640
# 980  0.101501  0.228332
# 981  0.164428  0.574893
# 982  0.155707  0.234721
# 983  0.231834  0.774091
# 984  0.099375  0.440331
# 985  0.372696  0.963829
# 986  0.830825  1.883936
# 987  0.502806  0.858740
# 988  0.504839  0.962927
# 989  0.115748  0.300850
# 990  0.178130  0.426487
# 991  0.187886  0.603033
# 992  0.131624  0.430956
# 993  0.338857  0.746949
# 994  0.315096  1.237490
# 995  0.065958  0.374779
# 996  0.161239  0.300186
# 997  0.307824  0.636176
#
# [998 rows x 54 columns]

# %% [markdown]
# ### Preparing data for Training ##

# %%
Norm=Norm.drop(['Reviews','clean_text','Text_length'],axis=1) # normalized
Not_Norm=Not_Norm.drop(['Reviews','clean_text','Text_length'],axis=1) #not-normalized

# %% [markdown]
# ### Y-Label ###

# %%
Y_Norm = df['sentiments']
Y_Not_Norm = df['sentiments']

# %%
Norm=Norm.drop(['sentiments'],axis=1)
Not_Norm=Not_Norm.drop(['sentiments'],axis=1)

# %% [markdown]
# ### Training using different kinds of Algorithm and Testing (by finding accuracy score and f1_score)  ###

# %%
X_Train_Not_Norm,X_Test_Not_Norm,Y_Train_Not_Norm,Y_Test_Not_Norm=train_test_split(Not_Norm,Y_Not_Norm,test_size=0.2,
                                                                                   random_state=1) # not-normalized

# %%
X_Train_Norm,X_Test_Norm,Y_Train_Norm,Y_Test_Norm=train_test_split(Norm,Y_Norm,test_size=0.2,
                                                                                   random_state=1) # normalized

# %% [markdown]
# ## Not-Normalized  model training##

# %% [markdown]
# ## Logistic Regression ##

# %%
lg = LogisticRegression()
lg.fit(X_Train_Not_Norm,Y_Train_Not_Norm)
predict = lg.predict(X_Test_Not_Norm)
print("Accuracy : {:.2f} %".format(accuracy_score(Pred,Y_Test_Not_Norm)*100))
print("F1-Score : {:.2f} ".format(f1_score(Pred,Y_Test_Not_Norm)))
# Out:
# Accuracy : 53.50 %
# F1-Score : 0.53

# %% [markdown]
# ## Hyperparameter tuning ##

# %%
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000] }
clf = GridSearchCV(LogisticRegression(penalty='l2'), param_grid)
clf.fit(X_Train_Not_Norm, Y_Train_Not_Norm)
clf.best_estimator_.C
# Out:
# 1000

# %% [markdown]
# after tuning  C is found to be 1000 as best estimator

# %%
lg = LogisticRegression(C=1000)
lg.fit(X_Train_Not_Norm,Y_Train_Not_Norm)
predict = lg.predict(X_Test_Not_Norm)
print("Accuracy : {:.2f} %".format(accuracy_score(predict,Y_Test_Not_Norm)*100))
print("F1-Score : {:.2f} ".format(f1_score(predict,Y_Test_Not_Norm)))
f1 = accuracy_score(predict,Y_Test_Not_Norm)
# Out:
# Accuracy : 59.50 %
# F1-Score : 0.55

# %% [markdown]
#  both accurcy score and f1_score increases
# ## Naive Bayes ##

# %%
Nb=GaussianNB()
Nb.fit(X_Train_Not_Norm,Y_Train_Not_Norm)
Pred=Nb.predict(X_Test_Not_Norm)
print("Accuracy : {:.2f} %".format(accuracy_score(Pred,Y_Test_Not_Norm)*100))
print("F1-Score : {:.2f} ".format(f1_score(Pred,Y_Test_Not_Norm)))
f2=accuracy_score(Pred,Y_Test_Not_Norm)
# Out:
# Accuracy : 56.00 %
# F1-Score : 0.35

# %% [markdown]
# since accuracy_score is less than logistic regression,we won't consider it

# %% [markdown]
# ## SVM ##

# %%
sv = SVC()
sv.fit(X_Train_Not_Norm,Y_Train_Not_Norm)
pred = sv.predict(X_Test_Not_Norm)
print("Accuracy : {:.2f} %".format(accuracy_score(pred,Y_Test_Not_Norm)*100))
print("F1-Score : {:.2f} ".format(f1_score(pred,Y_Test_Not_Norm)))
# Out:
# Accuracy : 53.50 %
# F1-Score : 0.44

# %% [markdown]
# accuracy is very less than logistic regression so we won't work for hyperparameter tuning.

# %% [markdown]
# ## Random Forest ##

# %%
Rfc=RandomForestClassifier(random_state=12)
Rfc.fit(X_Train_Not_Norm,Y_Train_Not_Norm)
Pred=Rfc.predict(X_Test_Not_Norm)
print("Accuracy : {:.2f} %".format(accuracy_score(Pred,Y_Test_Not_Norm)*100))
print("F1-Score : {:.2f} ".format(f1_score(Pred,Y_Test_Not_Norm)))
# Out:
# Accuracy : 55.00 %
# F1-Score : 0.53

# %% [markdown]
# ## Hyperparameter tuning##

# %%
rf_params = { 
    'n_estimators': [200,300,600],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth':np.arange(5,15,1)
}

gs_random = GridSearchCV(estimator=rf, param_grid=rf_params, cv= 4)
gs_random.fit(X_Train_Not_Norm, Y_Train_Not_Norm)
print (gs_random.best_params_)
# Out:
# {'max_depth': 14, 'max_features': 'log2', 'n_estimators': 200}

# %% [markdown]
# best parameters are fetched after tuning

# %%
Rfc=RandomForestClassifier(random_state=200,max_depth= 14, max_features='log2', n_estimators= 200)
Rfc.fit(X_Train_Not_Norm,Y_Train_Not_Norm)
Pred=Rfc.predict(X_Test_Not_Norm)
print("Accuracy : {:.2f} %".format(accuracy_score(Pred,Y_Test_Not_Norm)*100))
print("F1-Score : {:.2f} ".format(f1_score(Pred,Y_Test_Not_Norm)))
f4 = accuracy_score(Pred,Y_Test_Not_Norm)
# Out:
# Accuracy : 55.50 %
# F1-Score : 0.55

# %% [markdown]
# both accurcy score and f1_score increases and reaches 55.5%.

# %% [markdown]
# ## Normalized model training ##

# %% [markdown]
# ## Logistic Regression##

# %%
LG = LogisticRegression()
LG.fit(X_Train_Norm,Y_Train_Norm)
PredicT = LG.predict(X_Test_Norm)
print("Accuracy : {:.2f} %".format(accuracy_score(PredicT,Y_Test_Norm)*100))
print("F1-Score : {:.2f} ".format(f1_score(PredicT,Y_Test_Norm)))
# Out:
# Accuracy : 54.50 %
# F1-Score : 0.50

# %% [markdown]
# ## Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000] }
clf = GridSearchCV(LogisticRegression(penalty='l2'), param_grid)
clf.fit(X_Train_Norm, Y_Train_Norm)
clf.best_estimator_.C
# Out:
# 1000

# %% [markdown]
# C hyperparameter is found after Tuning

# %%
LG1 = LogisticRegression(C=1000)
LG1.fit(X_Train_Norm,Y_Train_Norm)
PrediCT = LG1.predict(X_Test_Norm)
print("Accuracy : {:.2f} %".format(accuracy_score(PrediCT,Y_Test_Norm)*100))
print("F1-Score : {:.2f} ".format(f1_score(PrediCT,Y_Test_Norm)))
F1=accuracy_score(PrediCT,Y_Test_Norm)
# Out:
# Accuracy : 59.50 %
# F1-Score : 0.55

# %% [markdown]
# both accuracy score and f1_score increases to a good level

# %% [markdown]
# ## Naive-Bayes

# %%
NB=GaussianNB()
NB.fit(X_Train_Norm,Y_Train_Norm)
PRED=NB.predict(X_Test_Norm)
print("Accuracy : {:.2f} %".format(accuracy_score(Pred,Y_Test_Norm)*100))
print("F1-Score : {:.2f} ".format(f1_score(PRED,Y_Test_Norm)))
F2 = accuracy_score(Pred,Y_Test_Norm)
# Out:
# Accuracy : 55.50 %
# F1-Score : 0.35

# %% [markdown]
# accuracy is low than logistic regression so we won't consider it.

# %% [markdown]
# ## SVM

# %%
SV = SVC()
SV.fit(X_Train_Norm,Y_Train_Norm)
PRed = SV.predict(X_Test_Norm)
print("Accuracy : {:.2f} %".format(accuracy_score(PRed,Y_Test_Norm)*100))
print("F1-Score : {:.2f} ".format(f1_score(PRed,Y_Test_Norm)))
# Out:
# Accuracy : 53.50 %
# F1-Score : 0.44

# %% [markdown]
# Accuracy is not upto the mark

# %% [markdown]
# ## Random Forest##

# %%
Rf = RandomForestClassifier(random_state=200)
Rf.fit(X_Train_Norm,Y_Train_Norm)
PREdict = Rf.predict(X_Test_Norm)
print("Accuracy : {:.2f} %".format(accuracy_score(PREdict,Y_Test_Norm)*100))
print("F1-Score : {:.2f} ".format(f1_score(PREdict,Y_Test_Norm)))
# Out:
# Accuracy : 54.50 %
# F1-Score : 0.47

# %% [markdown]
# ## Hyperparameter tuning

# %%
rf_params = { 
    'n_estimators': [200, 700],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth':np.arange(5,15,1)
}

gs_random = GridSearchCV(estimator=Rf, param_grid=rf_params, cv= 5)
gs_random.fit(X_Train_Norm, Y_Train_Norm)
print (gs_random.best_params_)
# Out:
# {'max_depth': 11, 'max_features': 'log2', 'n_estimators': 200}

# %% [markdown]
# best parameters are selected after Tuning.

# %%
Rf1 = RandomForestClassifier(random_state=100,max_depth= 11, max_features= 'log2', n_estimators= 200)
Rf1.fit(X_Train_Norm,Y_Train_Norm)
PREDict = Rf1.predict(X_Test_Norm)
print("Accuracy : {:.2f} %".format(accuracy_score(PREDict,Y_Test_Norm)*100))
print("F1-Score : {:.2f} ".format(f1_score(PREDict,Y_Test_Norm)))
F4 = accuracy_score(PREDict,Y_Test_Norm)
# Out:
# Accuracy : 55.50 %
# F1-Score : 0.56

# %% [markdown]
# there is an increase in accuracy score and f1-score slightly.

# %% [markdown]
# # OBSERVATIONS #

# %% [markdown]
# ##  For Not-Normalized data

# %%
Accuracy = [f1,f2,f3,f4]

Algo = ['LogisticRegression','GaussianNB','SVM(rbf)','Random Forest']

# %%
sns.barplot(y=Accuracy,x=Algo,data=df)

# %% [markdown]
# Logistic Regression has highest accuracy_score

# %% [markdown]
# ## for Normalized data

# %%
Accuracy = [F1,F2,F3,F4]

Algo = ['LogisticRegression','GaussianNB','SVM(rbf)','Random Forest']

# %%
sns.barplot(x=Algo,y=Accuracy)

# %% [markdown]
# Logistic Regression has highest accuracy_score
# ### Conclusion

# %% [markdown]
# * Logistic Regression has highest accuracy than any other model for both the cases(Normalized and Not-Normalized datasets).
# * Got 59.5% accuracy for not-normalized and normalized data using Logistic Regression technique<br>
# * This model can analyse any reviews' sentiments nearly upto 50% correctness which is an average performance of the model.<br>
# * After performing Hyperparameter-tuning accuracy_score and f1_score increases<br>
# * All the 4 models differ in scores from each other.<br>
# * Logistic Regression and Random-Forest modelling techniques performs the best after Tuning(Thus tuning is very necessary :)). <br>
# * Tuning is done to avoid overfitting and underfitting of the data and for removing some kind of noises.<br>
# * Collected data is not skewed much (i.e. both positive and negative reviews differ slightly)<br>
