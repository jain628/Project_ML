# %% [markdown]
# # IMDB Review Classification using Word Embeddings(GloVe) #
# ## PROBLEM STATEMENT
# In this project we will classify the IMDB reviews for positive and negative reviews using sentiment analysis or emotion AI.<BR>
#
# ## What is Sentiment Analysis?
# In essence, it is the process of determining the emotional tone behind a series of words, used to gain an understanding of the<br>the attitudes, opinions and emotions expressed within an online mention.<br>
#
# ## What is IMDB?
# IMDb, also known as Internet Movie Database, is an online database of information related to world films, television programs,<br>home videos and video games, and internet streams, including cast, production crew and personnel biographies, plot <br>summaries, trivia, and fan reviews and ratings
#
# ## How to perform Classification on Reviews using Sentiment Analysis?##

# %% [markdown]
# ## Steps involved to perform sentiment analysis on given data set
# ## Step 1: Get some sentiment examples
# IMDB review dataset is loaded<br>
# ## Step 2: Extract features from examples
# Transform each example into a feature vector.<br>
# Here we are using GloVe(Global Vectors) Word Embeddings for feature vectors.
# ## What is GloVe?
# GloVe stands for global vectors for word representation. It is an unsupervised learning algorithm developed by Stanford for generating word embeddings by aggregating global word-word co-occurrence matrix from a corpus.
# <br>
# ## What are Word Embeddings?
# In very simplistic terms, Word Embeddings are the texts converted into numbers and there may be different numerical representations of the same text..
# What word2vec does is, it updates the word vectors of a particular word by the probability of finding the word in the vicinity of the context words(i.e. The words around it).So the words which occur around same context words will have word vectors with much similarity.
# Ex. ‘need’ and ‘required’ generally have the same context words around it and thus making them similar in meaning. So, the word vectors of ‘need’ and ‘required’ will be very much similar.
#
# In this project we will be using a variation of word2vec i.e. GloVe(Global Vectors for Word Representation by Jeffrey Pennington, Richard Socher, and Christopher D. Manning. 2014).
# We will use pre-trained word vectors in the project that is open sourced in the Stanford website.
#
# ## Step 3: Train the parameters
# This is where your model will learn from the data. There are multiple ways of using features to generate an output, algorithms<br> used in this dataset are Logistic Regression,Naive Bayes, SVM and Decision Trees.<br>
# ## Step 4: Test the model
# After we have trained the parameters to fit the training data, we have to make sure our model generalizes to new data, because <br>it's really easy to overfit. The general way of regularizing the model is to prevent parameters from having extreme values.
# and thus this model uses GridSearchCV model for hyperparameter tuning.
# ## Why GridSearchCV for Tuning?
# GridSearchCV lets you combine an estimator with a grid search preamble to tune hyper-parameters. The method picks the optimal <br>parameter from the grid search and uses it with the estimator selected by the user. GridSearchCV inherits the methods from <br>the classifier, so yes, you can use the .score, .predict, etc.. methods directly through the GridSearchCV interface.
# ## Step 5: Compare the Models and derive Observations

# %% [markdown]
# ### lets follow the steps!###

# %% [markdown]
# import all necessary modules

# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from sklearn.model_selection  import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from gensim.scripts.glove2word2vec import glove2word2vec
from gensim.models import KeyedVectors
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,f1_score
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv("imdb_labelled11.csv")

# %% [markdown]
# ## Data Visualization ##

# %%
df.head()
# Out:
#                                              Reviews  sentiments
# 0  A very, very, very slow-moving, aimless movie ...         0.0
# 1  Not sure who was more lost - the flat characte...         0.0
# 2  Attempting artiness with black & white and cle...         0.0
# 3       Very little music or anything to speak of.           0.0
# 4  The best scene in the movie was when Gerardo i...         1.0

# %%
df.describe(include='all')
# Out:
#                                  Reviews  sentiments
# count                               1000  997.000000
# unique                               997         NaN
# top     Definitely worth checking out.           NaN
# freq                                   2         NaN
# mean                                 NaN    0.498495
# std                                  NaN    0.500249
# min                                  NaN    0.000000
# 25%                                  NaN    0.000000
# 50%                                  NaN    0.000000
# 75%                                  NaN    1.000000
# max                                  NaN    1.000000

# %%
df.shape
# Out:
# (1000, 2)

# %% [markdown]
# ### check for any missing value ###

# %%
df.isnull().values.any()
# Out:
# True

# %% [markdown]
#  Need to repair<br>
#  Find mean<br>
#  Impute the missing data with mean

# %%
df=df.fillna(df.mean())
df
# Out:
#                                                Reviews  sentiments
# 0    A very, very, very slow-moving, aimless movie ...         0.0
# 1    Not sure who was more lost - the flat characte...         0.0
# 2    Attempting artiness with black & white and cle...         0.0
# 3         Very little music or anything to speak of.           0.0
# 4    The best scene in the movie was when Gerardo i...         1.0
# 5    The rest of the movie lacks art, charm, meanin...         0.0
# 6                                  Wasted two hours.           0.0
# 7    Saw the movie today and thought it was a good ...         1.0
# 8                                 A bit predictable.           0.0
# 9    Loved the casting of Jimmy Buffet as the scien...         1.0
# 10                And those baby owls were adorable.           1.0
# 11   The movie showed a lot of Florida at it's best...         1.0
# 12   The Songs Were The Best And The Muppets Were S...         1.0
# 13                                   It Was So Cool.           1.0
# 14   This is a very "right on case" movie that deli...         1.0
# 15   It had some average acting from the main perso...         0.0
# 16   This review is long overdue, since I consider ...         1.0
# 17   I'll put this gem up against any movie in term...         1.0
# 18   It's practically perfect in all of them  a tr...         1.0
# 19    The structure of this film is easily the most...         1.0
# 20   I can think of no other film where something v...         1.0
# 21   In other words, the content level of this film...         1.0
# 22   How can anyone in their right mind ask for any...         1.0
# 23   It's quite simply the highest, most superlativ...         1.0
# 24   Yes, this film does require a rather significa...         1.0
# 25       This short film certainly pulls no punches.           0.0
# 26   Graphics is far from the best part of the game.           0.0
# 27   This is the number one best TH game in the ser...         1.0
# 28                          It deserves strong love.           1.0
# 29                             It is an insane game.           1.0
# ..                                                 ...         ...
# 970  Enough can not be said of the remarkable anima...         1.0
# 971  The art style has the appearance of crayon/pen...         1.0
# 972  If you act in such a film, you should be glad ...         0.0
# 973  This one wants to surf on the small wave of sp...         0.0
# 974  If you haven't choked in your own vomit by the...         0.0
# 975  Still, it makes up for all of this with a supe...         1.0
# 976  Just consider the excellent story, solid actin...         1.0
# 977  Instead, we got a bore fest about a whiny, spo...         0.0
# 978  Then I watched it again two Sundays ago (March...         1.0
# 979       It is a very well acted and done TV Movie.           1.0
# 980  Judith Light is one of my favorite actresses a...         1.0
# 981                I keep watching it over and over.           1.0
# 982                 It's a sad movie, but very good.           1.0
# 983  If you have not seen this movie, I definitely ...         1.0
# 984           She is as lovely as usual, this cutie!           1.0
# 985  Still it's quite interesting and entertaining ...         1.0
# 986                    ;) Recommend with confidence!           1.0
# 987  This movie is well-balanced with comedy and dr...         1.0
# 988  It was a riot to see Hugo Weaving play a sex-o...         1.0
# 989  :) Anyway, the plot flowed smoothly and the ma...         1.0
# 990  The opening sequence of this gem is a classic,...         1.0
# 991             Fans of the genre will be in heaven.           1.0
# 992                Lange had become a great actress.           1.0
# 993                It looked like a wonderful story.           1.0
# 994            I never walked out of a movie faster.           0.0
# 995  I just got bored watching Jessice Lange take h...         0.0
# 996  Unfortunately, any virtue in this film's produ...         0.0
# 997                   In a word, it is embarrassing.           0.0
# 998                               Exceptionally bad!           0.0
# 999  All in all its an insult to one's intelligence...         0.0
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### Re-check for missing values###

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### convert sentiments type to int from float for easy understanding ###
# ### 0 -- Negative review
# ### 1 --Positive review

# %%
df['sentiments'] = df['sentiments'].apply(lambda x: int(x))
df['sentiments']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
# 5      0
# 6      0
# 7      1
# 8      0
# 9      1
# 10     1
# 11     1
# 12     1
# 13     1
# 14     1
# 15     0
# 16     1
# 17     1
# 18     1
# 19     1
# 20     1
# 21     1
# 22     1
# 23     1
# 24     1
# 25     0
# 26     0
# 27     1
# 28     1
# 29     1
#       ..
# 970    1
# 971    1
# 972    0
# 973    0
# 974    0
# 975    1
# 976    1
# 977    0
# 978    1
# 979    1
# 980    1
# 981    1
# 982    1
# 983    1
# 984    1
# 985    1
# 986    1
# 987    1
# 988    1
# 989    1
# 990    1
# 991    1
# 992    1
# 993    1
# 994    0
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: sentiments, Length: 1000, dtype: int64

# %% [markdown]
# ### Let's visualize data###
# ## EDA##

# %%
df['sentiments'].hist(figsize=(10,10))

# %% [markdown]
# Negative reviews are slightly more than positive reviews.<br>
# which shows that people are not satisfied.

# %% [markdown]
# ### lets find out high frequecy of negative and positive words###

# %%
reviews = df.Reviews.str.cat(sep=' ')
                                         #function to split text into word
tokens = word_tokenize(reviews)
vocabulary = set(tokens)                  #removing duplicates
print(len(vocabulary))
frequency_dist = nltk.FreqDist(vocabulary)
sorted(frequency_dist,key=frequency_dist.__getitem__, reverse=True)[0:50]
# Out:
# 3420
# ['twice',
#  'trysts',
#  'ordeal',
#  'super',
#  'editing',
#  'recent',
#  'nonetheless',
#  'twist',
#  'Bergen',
#  'interacting',
#  'forced',
#  'class',
#  'someone',
#  'hockey',
#  'trilogy',
#  'had',
#  'shed',
#  '54',
#  'renowned',
#  'ridiculous',
#  'back',
#  'lower',
#  'Ackerman',
#  'grace',
#  'numbers',
#  'watching',
#  'forgettable',
#  'often',
#  'feel-good',
#  '90',
#  'schizophrenic',
#  'treachery',
#  'ho',
#  'continually',
#  'acting-wise',
#  'Ponyo',
#  'efforts',
#  'DonLevy',
#  'heads',
#  'credit',
#  'climax',
#  'poet',
#  'meld',
#  'where',
#  'MOVIE',
#  'parents',
#  'actions',
#  'art',
#  'goes',
#  'cruel']

# %%
stop_words = set(stopwords.words('english')) #stopwords are like very commomly used word(for eg. is,am,..etc.)
x=[i for i in tokens if i not in stop_words]
tokens = [w for w in vocabulary if w not in stop_words]
tokens
# Out:
# ['twice',
#  'trysts',
#  'ordeal',
#  'super',
#  'editing',
#  'recent',
#  'nonetheless',
#  'twist',
#  'Bergen',
#  'interacting',
#  'forced',
#  'class',
#  'someone',
#  'hockey',
#  'trilogy',
#  'shed',
#  '54',
#  'renowned',
#  'ridiculous',
#  'back',
#  'lower',
#  'Ackerman',
#  'grace',
#  'numbers',
#  'watching',
#  'forgettable',
#  'often',
#  'feel-good',
#  '90',
#  'schizophrenic',
#  'treachery',
#  'ho',
#  'continually',
#  'acting-wise',
#  'Ponyo',
#  'efforts',
#  'DonLevy',
#  'heads',
#  'credit',
#  'climax',
#  'poet',
#  'meld',
#  'MOVIE',
#  'parents',
#  'actions',
#  'art',
#  'goes',
#  'cruel',
#  'Brian',
#  'delights',
#  'Coppola',
#  'adorable',
#  'Sundays',
#  'Steve',
#  'male',
#  'weaker',
#  'portrayed',
#  'Plmer',
#  'coastal',
#  'court',
#  'ca',
#  'decent',
#  'jerky',
#  'bipolarity',
#  'hell',
#  'Gas',
#  'unbelievable',
#  'miss',
#  'obvious',
#  'dreams',
#  'romantic',
#  'Regardless',
#  'single',
#  'Peter',
#  'paint',
#  'dialogs',
#  'dollars',
#  'paced',
#  'sloppy',
#  'astronaut',
#  'clients',
#  'require',
#  'stinks',
#  'alike',
#  'Horse',
#  'contained',
#  'addition',
#  'Constantine',
#  'rejection',
#  'Blake',
#  'three',
#  'antithesis',
#  'oh',
#  'baaaaaad',
#  'Tony',
#  'pap',
#  'comfortable',
#  'And',
#  'ten',
#  'Sean',
#  'old-fashioned',
#  'faux',
#  'noir',
#  'understanding',
#  'Look',
#  'refreshing',
#  'akin',
#  'thinking',
#  'Speed',
#  'Judith',
#  'succeeds',
#  'site',
#  'living/working',
#  'intelligence',
#  'tears',
#  'f/x',
#  'One',
#  'SPOILER',
#  'McHattie',
#  'Florida',
#  'remaining',
#  'crayon/pencil',
#  'different',
#  'average',
#  'Fausa',
#  'Haggis',
#  'recover',
#  'Nicola',
#  'Im',
#  'draft',
#  'underlying',
#  'be-all',
#  'IS',
#  'understated',
#  'repertory',
#  '8',
#  'thoughts',
#  'THERE',
#  'Mansonites',
#  'Body',
#  'Dickens',
#  'take',
#  'Bennett',
#  'comprehensible',
#  'spiffy',
#  'behold',
#  'holding',
#  'acclaimed',
#  'accurate',
#  'stocking',
#  'blue/green-screen',
#  'intelligent',
#  'built',
#  'hip',
#  'graphics',
#  '8.15pm',
#  'brat',
#  'future',
#  'Instead',
#  'greatest',
#  'indication',
#  'makers',
#  'Ebola',
#  'half',
#  'impression',
#  'trinity',
#  'For',
#  'Hilarious',
#  'footage',
#  'cowardice',
#  'poetry',
#  'Riz',
#  'Snow',
#  'Awful',
#  'Ebay',
#  'sites',
#  'casting',
#  'underbite',
#  'Ishioka',
#  'together',
#  'great',
#  'shined',
#  'babysitting',
#  'WB',
#  'following',
#  'SO',
#  'Feeling',
#  'sum',
#  'discovering',
#  'chance',
#  'resume',
#  'foolish',
#  'famed',
#  'confidence',
#  'instruments',
#  'moral',
#  'Hayworth',
#  'damn',
#  'experiences',
#  'friendship',
#  'managed',
#  'screenplay',
#  'non-researched',
#  'self',
#  'perfect',
#  'Girolamo',
#  'Darren',
#  'Connery',
#  'Jim',
#  'audio',
#  'confirm',
#  'sequences',
#  'endlessly',
#  'Hence',
#  'well-balanced',
#  'Jerry',
#  'Things',
#  'miserable',
#  'stereotypically',
#  'late',
#  'might',
#  'strange',
#  'Punishment',
#  'horrified',
#  'fantastic',
#  'acting',
#  'NO',
#  'Buy',
#  'whenever',
#  'mistakes',
#  'threshold',
#  'na',
#  'fingernails',
#  'Tale',
#  'related',
#  'generates',
#  'Ue',
#  'controversy',
#  'Giovanni',
#  'Harris',
#  'Rita',
#  'instant',
#  'example',
#  'power',
#  'Z',
#  'opening',
#  'lid',
#  'debated',
#  'evaluate',
#  'Play',
#  'journey',
#  'Jean',
#  'mexican',
#  'I',
#  'If',
#  'peculiarity',
#  'exciting',
#  'towards',
#  'type',
#  'exquisite',
#  'looked',
#  'makes',
#  'intoning',
#  'range',
#  "'re",
#  'warmth',
#  'n',
#  'humorous',
#  'voyage',
#  'Christopher',
#  'From',
#  'premise',
#  'viewing',
#  'mean',
#  'psychological',
#  'mainly',
#  'surf',
#  'knocked',
#  'pair',
#  'Some',
#  'marbles',
#  'terror',
#  'begin',
#  'cross',
#  'finished',
#  'value',
#  'loads',
#  'Hugo',
#  'ed',
#  'hes',
#  'PLOT',
#  'Sci-fi',
#  'imaginable',
#  'really',
#  'identifies',
#  'hands',
#  'disbelief',
#  'General',
#  'Armageddon',
#  'lust',
#  '``',
#  'Candace',
#  'failed',
#  'Academy',
#  'treatments',
#  'Puppet',
#  'purity',
#  "'film",
#  'narrative',
#  'sat',
#  'repeated',
#  'part',
#  'free',
#  'kinda',
#  'talents',
#  'fishnet',
#  '70000',
#  'title',
#  'Sandra',
#  'talk',
#  'smoothly',
#  'delivered',
#  'always',
#  'lines',
#  'Mickey',
#  'sci',
#  'How',
#  'length',
#  'backed',
#  'Cast',
#  '.',
#  'rips',
#  'boss',
#  'Howell',
#  'tying',
#  'hour',
#  'continue',
#  'courtroom',
#  'Anthony',
#  'depends',
#  'excellent',
#  'exceptional',
#  '95',
#  'God',
#  'Slideshow',
#  'store',
#  'foreign',
#  'brilliance',
#  'hours',
#  'marriage',
#  'may',
#  'SEE',
#  'provided',
#  'Thunderbirds',
#  'tries',
#  'versus',
#  'fx',
#  'Tom',
#  'past',
#  'choices',
#  'universe',
#  'memories',
#  'volcano',
#  'brainsucking',
#  'air',
#  'flicks',
#  'below-par',
#  'screen..James',
#  'everybody',
#  'war',
#  'Howe',
#  'barely',
#  'monolog',
#  'top',
#  'talent',
#  'continuously',
#  'Foxx',
#  'Groove',
#  'twirling',
#  'looks',
#  'oriented',
#  'acted',
#  'i.e',
#  'low-budget',
#  'insomniacs',
#  'either',
#  'Lewis',
#  'Perabo',
#  'far',
#  'escalating',
#  'pictures',
#  'reporter',
#  'Vivian',
#  'shot',
#  'producer',
#  'disappointing',
#  'handle',
#  'Brilliant',
#  'Horror',
#  'enjoyed',
#  'voice',
#  'CLASSIC',
#  'received',
#  'flat',
#  'naked.Billy',
#  'Funny',
#  'fisted',
#  'M',
#  'unforgettable',
#  'fails',
#  'reading',
#  'bat',
#  'menacing',
#  'control',
#  'quiet',
#  'blah',
#  'dark',
#  'Aside',
#  'raver',
#  'question',
#  'He',
#  'warts',
#  'Kathy',
#  'singing',
#  'hand-drawn',
#  'sinking',
#  'number',
#  'swamp',
#  'AND',
#  'Americans',
#  'atrocious',
#  'seem',
#  'Frances',
#  'things',
#  'disturbing',
#  'switched',
#  'Southern',
#  'IMDB',
#  'scripts',
#  'win',
#  'thought-provoking',
#  'While',
#  'pure',
#  'nun',
#  '4',
#  'local',
#  'Director',
#  'easy',
#  'fun',
#  'contributory',
#  'Excellent',
#  'sibling',
#  'Cotton',
#  'apt',
#  'pointless',
#  'blood',
#  'delivers',
#  'Rubin',
#  'forces',
#  'see',
#  'lilt',
#  'avoided',
#  'video',
#  'Smith',
#  'old',
#  'jobs',
#  'Aailiyah',
#  'WHAT',
#  'spoiled',
#  'carry',
#  'Pitch',
#  'small',
#  'coach',
#  'Helms',
#  'convincing',
#  'film',
#  'pitiful',
#  'It',
#  'complete',
#  'insane',
#  'one',
#  'earlier',
#  'Show',
#  'sequence',
#  'gently',
#  'show.These',
#  'Babie',
#  'soundtrack',
#  'exteriors',
#  'abroad',
#  'Allison',
#  'weight',
#  'jet',
#  'self-discovery',
#  'veteran',
#  'Rating',
#  'Seuss',
#  'coherent',
#  'bother',
#  'freedom',
#  'classic',
#  'whiny',
#  'Parker',
#  'character',
#  'shallow',
#  'edge',
#  'basic',
#  'idea',
#  'shows',
#  'whatever',
#  'sit',
#  'Negulesco',
#  'Macbeth',
#  'crap',
#  'girlfriend/boyfriend',
#  'material',
#  'borrowed',
#  '.stylized',
#  'Being',
#  'VERY',
#  'voice-overs',
#  'shenanigans',
#  'Hayao',
#  'But',
#  'young',
#  'Canada',
#  'California',
#  'fact',
#  'consequences',
#  'deserving',
#  'bakery',
#  'Wayne',
#  '1998',
#  'Work',
#  'last',
#  'Jonah',
#  'crocdodile',
#  'redeemed',
#  'masculinity',
#  'prone',
#  'supposedly',
#  'admitted',
#  'Aurvåg',
#  'full',
#  'imaginative',
#  'pedestal',
#  'savor',
#  'effort',
#  'SETS',
#  'readers',
#  'McLaglen',
#  'Chodorov',
#  'bad',
#  'Ann',
#  'dependant',
#  'ROAD',
#  'almost',
#  'rocks',
#  'direction',
#  'Fire',
#  'told',
#  'series',
#  'phenomenal',
#  'touching',
#  'suck',
#  'cat',
#  'strokes',
#  'wont',
#  'spew',
#  'possible',
#  'suited',
#  'write',
#  'collective',
#  'timers',
#  'You',
#  'definitely',
#  'contrast',
#  'can-do',
#  'Boyle',
#  'superficial',
#  'terrible',
#  'note',
#  'sappiest',
#  "'Ive",
#  'B',
#  'unethical',
#  'wasting',
#  'Light',
#  'LaSelva',
#  'including',
#  'Regrettably',
#  'reason',
#  'heroine',
#  'Plus',
#  'indie',
#  'Falwell',
#  'Angeles',
#  'animated',
#  'spoilers',
#  'existential',
#  'well',
#  'frankly',
#  'higher',
#  'heaven',
#  'knew',
#  'right',
#  'Monica',
#  'surely',
#  'relations',
#  'Shirley',
#  'Ventura',
#  'century',
#  'Otherwise',
#  'Their',
#  'look',
#  'FX',
#  'tremendous',
#  'Avoid',
#  'Daughter',
#  'Lassie',
#  'head-over-heels',
#  'running',
#  'In',
#  'self-sacrifice',
#  'bible',
#  'monster',
#  'nuns',
#  'Snider',
#  'predictable',
#  'villains',
#  'doctor',
#  'unmoving',
#  'Charlie',
#  'uninteresting',
#  'characters',
#  'ALL',
#  'highly',
#  'Knightley',
#  'review',
#  'shortlist',
#  'unmatched',
#  'struggle',
#  'serious',
#  'Havilland',
#  'BAD',
#  'emptiness',
#  'realize',
#  'release',
#  'bond',
#  'reviews',
#  'hill',
#  'undertone',
#  'Park',
#  'Later',
#  'mention',
#  "'ll",
#  'middle-aged',
#  'side',
#  'author',
#  'powerhouse',
#  'cheekbones',
#  'night',
#  'less',
#  'Lance',
#  'outward',
#  'considering',
#  'Despite',
#  'touch',
#  'Was',
#  'convey',
#  'interest',
#  'Pulling',
#  'stealing',
#  'allow',
#  'senses',
#  'logic',
#  'Townsend',
#  'function',
#  'Okay',
#  'ability',
#  'couple',
#  'filmed',
#  'deserves',
#  'honestly',
#  "so-bad-it's-memorable",
#  'rent',
#  'Nine',
#  'admiration',
#  'scary',
#  'Considering',
#  'fest',
#  'Bad',
#  'sing',
#  'Summary',
#  'Balls',
#  'hide',
#  'particular',
#  'Hackneyed',
#  'eyes',
#  'critic',
#  'Impact',
#  'latest',
#  'bonus',
#  'applauded',
#  '1973',
#  'directors',
#  '!',
#  'feet',
#  'tsunami',
#  'selections',
#  'generic',
#  'regret',
#  'wholesome',
#  'Waste',
#  'wide',
#  'apart',
#  'Loewenhielm',
#  'whole',
#  'deserved',
#  'William',
#  'comments',
#  'camp',
#  'mollusk',
#  'afternoon',
#  'Sorrentino',
#  'cute',
#  'There',
#  'intentions',
#  'directed',
#  'Special',
#  'etc',
#  'aesthetically',
#  'desert',
#  'zombie-students',
#  'naughty',
#  '20th',
#  'ass',
#  'amaze',
#  'superb',
#  'taken',
#  'choice',
#  'Started',
#  'attractive',
#  'believed',
#  'expectations',
#  'collect',
#  'Tonight',
#  'another',
#  'cardboard',
#  'She',
#  'certainly',
#  '.an',
#  'cover',
#  'latifa',
#  'circumstances',
#  'interim',
#  'candle',
#  'skip',
#  'Kevin',
#  'Shakespears',
#  'convince',
#  'horrendous',
#  'TV',
#  'team',
#  'features',
#  'towers',
#  "'m",
#  'screenwriter',
#  'colours',
#  'taking',
#  'buildings',
#  'thing',
#  'rise',
#  'outside',
#  'They',
#  'imagine',
#  'stratus',
#  'incendiary',
#  'entertained',
#  'nice',
#  'explanation',
#  'actresses',
#  'Word',
#  'questioning',
#  'Season',
#  'Bop',
#  'semi',
#  'falls',
#  'uplifting',
#  'phony',
#  'crackles',
#  'offer',
#  'truly',
#  'Custer',
#  'system',
#  'Water',
#  'upper',
#  'Conclusion',
#  'lieutenant',
#  'call',
#  'dislike',
#  'crew',
#  'bland',
#  'appears',
#  'realised',
#  'eating',
#  'gung',
#  'would-be',
#  'overall',
#  'sack',
#  'pull',
#  'comment',
#  'performances',
#  'Enough',
#  'age',
#  'thriller',
#  'la',
#  'Ed',
#  'Then',
#  'THINKING',
#  'score',
#  'Traffic',
#  'Girl',
#  'Up',
#  'unrealistic',
#  'stunning',
#  'Never',
#  'wrap',
#  'Jaclyn',
#  'state-of-the-art',
#  'close-ups',
#  'errors',
#  'bore',
#  'huge',
#  'poler',
#  'conclusion',
#  'killer',
#  'self-indulgent',
#  'Phantasm',
#  'poised',
#  'sells',
#  'continuation',
#  'fifties',
#  'relate',
#  'disparate',
#  'slimy',
#  'sisters',
#  'sure',
#  'unremarkable',
#  'Buffet',
#  'desperately',
#  'excruciatingly',
#  'Doctor',
#  'trash',
#  'Channel',
#  'classical',
#  'whether',
#  'made',
#  'whatsoever',
#  'Seriously',
#  'never',
#  'Mother',
#  'era',
#  'drag',
#  'bully',
#  'portrayals',
#  'touches',
#  'earth',
#  'Had',
#  'ranks',
#  'realized',
#  'released',
#  'Go',
#  'relaxing',
#  'Taelons',
#  'talented',
#  'amateurish',
#  'expected',
#  'appropriate',
#  'rating',
#  'difference',
#  '1-10',
#  'younger',
#  'unnecessary',
#  'joy',
#  'subject',
#  'must-have',
#  'keeps',
#  'expression',
#  'worthy',
#  'teen',
#  'except',
#  'subversive',
#  'rendition',
#  'conflict',
#  'impressed',
#  'film-maker',
#  'tacky',
#  'depending',
#  'Her',
#  'keep',
#  'See',
#  'sometimes',
#  'Studio',
#  'worst',
#  'heart',
#  'looking',
#  'watchable',
#  'shell',
#  'rubbish',
#  'believable',
#  'Affleck',
#  'whites',
#  'Casting',
#  'typical',
#  'terminology',
#  'falling',
#  'torture',
#  'Imperial',
#  'sick',
#  'A+',
#  'Luv',
#  'notable',
#  'UPA',
#  'freshness',
#  'curtain',
#  'setting',
#  'trumpeter',
#  'containing',
#  'TARDIS',
#  '10-Oct',
#  'minutes',
#  'Sydney',
#  'amusing',
#  'smile',
#  'tract',
#  'began',
#  'provokes',
#  'translating',
#  'effective',
#  'sitcoms',
#  'WRITTEN',
#  'happen',
#  'Bertolucci',
#  'known',
#  'public',
#  'Editing',
#  '0/10',
#  'Sam',
#  'fish',
#  'jealousy',
#  'repeating',
#  'innocence',
#  'commercial',
#  'fame',
#  'day',
#  'actually',
#  'dialog',
#  'says',
#  'soon',
#  'The',
#  'living',
#  'outlandish',
#  'ends',
#  'Generally',
#  'cute.But',
#  'paid',
#  'loose',
#  'avoid',
#  'bonuses',
#  'aspects',
#  'enjoyable',
#  'accolades',
#  'ole',
#  'underacting',
#  ';',
#  'horror/suspense',
#  'Ironically',
#  'unrestrained',
#  'falsely',
#  'salesman',
#  'incredible',
#  'accessible',
#  'Shatner',
#  'nerves',
#  'mini-series',
#  'facing',
#  'pointillistic',
#  'supernatural',
#  'set',
#  'it.Buy',
#  'ground-breaking',
#  'soap',
#  'Edward',
#  'wants',
#  'give',
#  'seemed',
#  'American',
#  'doubt',
#  'None',
#  ...]

# %%
stemmer = PorterStemmer()   #
def preprocess(raw_tweet, flag):
    letters_only = re.sub("[^a-zA-Z]", " ",raw_tweet)
    
    # change sentence to lower case
    letters_only = letters_only.lower()

    # tokenize into words
    words = letters_only.split()
    
    # remove stop words                
    words = [w for w in words if not w in stopwords.words("english")]
    
    #Stemming
    words = [stemmer.stem(word) for word in words]
    
    if flag == 1:
        return(" ".join(words))
    else:
        return(len(words))

# %% [markdown]
# ### Why stemming ?
# In the context of machine learning based NLP, stemming makes your training data more dense. It reduces the size of the<br> dictionary and here we use it for visualizing word cloud only.

# %%
df['clean_text']=df['Reviews'].apply(lambda x: preprocess(x, flag=1)) #cleaning data
df['Tweet_length']=df['Reviews'].apply(lambda x: preprocess(x, flag=2)) # finding minimum length

# %%
Neg=df[df['sentiments']==0]
Neg_Token=list()
for i in Neg['clean_text']:
    if 'movi' in i or 'film' in i:
        pass
    else:
        Neg_Token=Neg_Token+i.split(" ")
Neg_Corpus=" ".join(Neg_Token)
wordcloud=WordCloud(height=800,width=800,background_color='black').generate(Neg_Corpus)

plt.figure(figsize=(15,10))
plt.title("WordCloud For Negative Reviews \n")
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# ### Highly used words in Negative reviews: ###
#  1.bad<br>
#  2.act<br>
#  3.even<br>
#  4.time<br>
#  5.plot<br>
#  6.script<br>
#  7.character

# %%
Pos=df[df['sentiments']==1]
Pos_Token=list()
for i in Pos['clean_text']:
    if 'movi' in i or 'film' in i:
        pass
    else:
        Pos_Token=Pos_Token+i.split(" ")
Pos_Corpus=" ".join(Pos_Token)
wordcloud=WordCloud(height=800,width=800,background_color='black').generate(Pos_Corpus)

plt.figure(figsize=(18,12))
plt.title("WordCloud For Positive Reviews \n")
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# ### Highly used words in Positive reviews: ###
#  1.good<br>
#  2.great<br>
#  3.love<br>
#  4.well<br>
#  5.character<br>
#  6.cast<br>
#  7.play

# %% [markdown]
# ## GloVe##

# %%
glove2word2vec(glove_input_file='glove.6B.50d.txt',word2vec_output_file="Vect.txt")
model=KeyedVectors.load_word2vec_format("Vect.txt")

# %% [markdown]
# Now let's Make 2 DataFrames, Normalised Sentence Vectors and Not-Normalised Sentence Vectors.<br>
# <br>
# ##### Not-Normalised Sentence Vectors=Sentence vector(S)[50-dim]= (word_vector(w1)+word_vector(w2)+word_vector(w3))
#
# ##### Normalised Sentence Vectors=Sentence vector normalized(S)[50-dim]= (word_vector(w1)+word_vector(w2)+word_vector(w3))/ (number of words)

# %% [markdown]
# ## summing vectors for text-reviews##
# ### Not-Normalized###

# %%
Def_List=[0]*50   #those factors which donot have value in glove are assigned 0
def Get_Sum(x,Def_List,ret_val):
    vec=Def_List
    for i in x:
        try:
            vec=np.add(vec,model[i])
        except:
            vec=np.add(vec,Def_List)
            continue
    return vec[ret_val]
Not_Norm=df
for i in range(50):
    Not_Norm['Feat'+str(i)]=Not_Norm['clean_text'].apply(Get_Sum,args=[Def_List,i])
Not_Norm
# Out:
#                                                Reviews  sentiments  \
# 0    A very, very, very slow-moving, aimless movie ...           0
# 23   10.905056   9.150004 -15.820015   8.864812  32.796990
# 24   18.864605  15.820592 -29.908792  17.214164  69.214411
# 25    9.667756   6.501624  -8.960509   8.483612  24.969950
# 26    7.399520   5.914720  -7.399895   5.332586  22.016811
# 27    6.232213   4.733977 -10.780906   7.811474  20.950720
# 28    9.684230   3.097374  -7.126624   6.706733  17.126910
# 29    1.621800   2.153640  -3.809741   2.717520   6.258970
# ..         ...        ...        ...        ...        ...
# 970   6.351322   5.609527 -10.130723   3.289708  22.982300
# 971  15.800650   9.485508 -17.686279  16.613206  53.736161
# 972  13.168040   8.976499 -14.632218  10.809669  41.511761
# 973  23.970103  15.036975 -25.837997  24.047854  60.230291
# 974  17.489245  10.675824 -25.802080  20.258604  54.185121
# 975  15.546401  13.104534 -16.738220  16.243626  48.750571
# 976  14.707062   6.774377 -15.612282  15.419388  36.678880
# 977  11.189360   5.607654 -17.775514  15.471455  37.009330
# 978  12.182513   8.943205 -27.841591  19.934129  55.938811
# 979   8.117950   2.885383  -8.746832   7.590996  12.762030
# 980  16.659325   7.207496 -20.130375  13.332891  44.084811
# 981   2.213549   2.341344  -2.913942   4.585643   7.803970
# 982   5.083290   1.030347  -6.438659   4.418810  10.315180
# 983   8.760890   5.458227 -12.922907   5.398303  23.740460
# 984   4.677569   1.569043  -3.921089   5.618497   7.833240
# 985   8.116023   6.642501 -11.799836  10.153766  30.447110
# 986   6.701170   3.682160  -8.410640   2.845960  17.886390
# 987  13.593653   5.424853 -19.522108  15.331021  37.552460
# 988  21.034799  17.855372 -30.882887  37.014699  77.187401
# 989   7.155390   6.745363 -18.972360  22.708219  34.265850
# 990  17.204746  11.762302 -19.556596  22.821245  42.041201
# 991   5.763310   3.528692  -5.812334   4.413740  13.616730
# 992   7.206510   4.741625  -7.795010   7.594056  19.121540
# 993   5.868208   2.838069  -7.951227   7.475203  22.342840
# 994   8.585199   4.588753  -8.023451   5.613253  16.767620
# 995   9.745339   4.626384 -12.942040  14.210372  27.563490
# 996  17.088471   9.398064 -19.366014   8.251503  50.501021
# 997   6.383970   2.525464  -5.016098   2.907030  15.160940
# 998   4.334180   2.442745  -3.341662   3.978077   8.364440
# 999   5.808486   5.120458 -13.243436  12.612205  26.577210
#
# [1000 rows x 54 columns]

# %% [markdown]
# ### Normalized ###

# %%
Def_List=[0]*50
def Get_Sum(x,Def_List,ret_val):
    vec=Def_List
    for i in x:
        try:
            vec=np.add(vec,model[i])
        except:
            vec=np.add(vec,Def_List)
            continue
    vec=np.divide(vec,len(vec))
    return vec[ret_val]

Norm=df
for i in range(50):
    Norm['Feat'+str(i)]=Not_Norm['clean_text'].apply(Get_Sum,args=[Def_List,i])
Norm
# Out:
#                                                Reviews  sentiments  \
# 0    A very, very, very slow-moving, aimless movie ...           0
# 1    Not sure who was more lost - the flat characte...           0
# 2    Attempting artiness with black & white and cle...           0
# 3         Very little music or anything to speak of.             0
# 4    The best scene in the movie was when Gerardo i...           1
# 5    The rest of the movie lacks art, charm, meanin...           0
# 17   put gem movi term screenplay cinematographi ac...            14
# 18   practic perfect true masterpiec sea faux maste...             7
# 19   structur film easili tightli construct histori...             7
# 20    think film someth vital import occur everi minut             8
# 21   word content level film enough easili fill doz...             9
# 22                     anyon right mind ask anyth movi             6
# 23       quit simpli highest superl form cinema imagin             7
# 24   ye film requir rather signific amount puzzl so...            14
# 25                     short film certainli pull punch             5
# 26                          graphic far best part game             5
# 27                        number one best th game seri             6
# 28                                  deserv strong love             3
# 29                                          insan game             2
# ..                                                 ...           ...
# 970                       enough said remark anim film             5
# 971  art style appear crayon pencil draw wonder col...             9
# 972   act film glad gonna drift away earth far possibl             9
# 973  one want surf small wave space movi deep impac...            13
# 974  choke vomit end cheap drama worthless dialogu ...            12
# 975  still make super end depict great sea vessel t...            11
# 976    consid excel stori solid act look film ad bonus             9
# 977     instead got bore fest whini spoil brat babysit             8
# 978  watch two sunday ago march th began realli enj...            13
# 979                              well act done tv movi             5
# 980  judith light one favorit actress think superb ...             9
# 981                                         keep watch             2
# 982                                      sad movi good             3
# 983                        seen movi definit recommend             4
# 984                                    love usual cuti             3
# 985               still quit interest entertain follow             5
# 986                                   recommend confid             2
# 987     movi well balanc comedi drama thoroughli enjoy             7
# 988  riot see hugo weav play sex obsess gay real es...            19
# 989     anyway plot flow smoothli male bond scene hoot             8
# 990  open sequenc gem classic cat n mous game follo...            11
# 991                                    fan genr heaven             3
# 992                           lang becom great actress             4
# 993                             look like wonder stori             4
# 994                             never walk movi faster             4
# 995              got bore watch jessic lang take cloth             7
# 996  unfortun virtu film product work lost regrett ...             8
# 997                                     word embarrass             2
# 998                                         except bad             2
# 999                insult one intellig huge wast money             6
#
#         Feat0     Feat1     Feat2     Feat3     Feat4     Feat5    ...     \
# 0   -0.083951  0.771993  0.531956  0.575461  0.240392 -0.055932    ...
# 1   -0.107213  0.599292  0.509455  0.522711  0.352843  0.100957    ...
# 2   -0.149438  1.583101  1.237275  1.271239  0.782292  0.047547    ...
# 3   -0.048592  0.317410  0.294384  0.271634  0.214501 -0.014636    ...
# 4   -0.028752  0.699131  0.605701  0.596852  0.230115 -0.003410    ...
# 5   -0.101205  0.775215  0.668737  0.625873  0.340217 -0.005086    ...
# 6   -0.071685  0.218390  0.155788  0.195246  0.069091 -0.026588    ...
# 7   -0.109343  0.811891  0.471225  0.659827  0.249986 -0.032127    ...
# 8   -0.025712  0.114568  0.128694  0.113925  0.076123  0.021846    ...
# 9   -0.065898  0.485673  0.431200  0.429723  0.253202 -0.085593    ...
# 10  -0.033019  0.169635  0.060614  0.136114  0.082602  0.060282    ...
# 11  -0.058396  0.666312  0.432848  0.511688  0.238636 -0.009250    ...
# 12  -0.048415  0.337416  0.313169  0.297721  0.193865 -0.018422    ...
# 13  -0.015787  0.081867  0.028881  0.072412  0.025440 -0.015317    ...
# 14  -0.044184  0.647988  0.479821  0.571617  0.229237  0.000469    ...
# 15  -0.032795  0.623529  0.484327  0.560564  0.248346  0.059991    ...
# 11  -0.266759  0.359047  0.606128
# 12  -0.146838  0.164720  0.331018
# 13  -0.039147  0.072485  0.067758
# 14  -0.383717  0.220409  0.746015
# 15  -0.263309  0.288744  0.710239
# 16  -0.522591  0.390189  1.278773
# 17  -0.619500  0.433184  1.387798
# 18  -0.276072  0.214752  0.833855
# 19  -0.401396  0.162949  0.852528
# 20  -0.418256  0.172651  0.677990
# 21  -0.356335  0.316713  0.896379
# 22  -0.324293  0.144922  0.486244
# 23  -0.316400  0.177296  0.655940
# 24  -0.598176  0.344283  1.384288
# 25  -0.179210  0.169672  0.499399
# 26  -0.147998  0.106652  0.440336
# 27  -0.215618  0.156229  0.419014
# 28  -0.142532  0.134135  0.342538
# 29  -0.076195  0.054350  0.125179
# ..        ...       ...       ...
# 970 -0.202614  0.065794  0.459646
# 971 -0.353726  0.332264  1.074723
# 972 -0.292644  0.216193  0.830235
# 973 -0.516760  0.480957  1.204606
# 974 -0.516042  0.405172  1.083702
# 975 -0.334764  0.324873  0.975011
# 976 -0.312246  0.308388  0.733578
# 977 -0.355510  0.309429  0.740187
# 978 -0.556832  0.398683  1.118776
# 979 -0.174937  0.151820  0.255241
# 980 -0.402607  0.266658  0.881696
# 981 -0.058279  0.091713  0.156079
# 982 -0.128773  0.088376  0.206304
# 983 -0.258458  0.107966  0.474809
# 984 -0.078422  0.112370  0.156665
# 985 -0.235997  0.203075  0.608942
# 986 -0.168213  0.056919  0.357728
# 987 -0.390442  0.306620  0.751049
# 988 -0.617658  0.740294  1.543748
# 989 -0.379447  0.454164  0.685317
# 990 -0.391132  0.456425  0.840824
# 991 -0.116247  0.088275  0.272335
# 992 -0.155900  0.151881  0.382431
# 993 -0.159025  0.149504  0.446857
# 994 -0.160469  0.112265  0.335352
# 995 -0.258841  0.284207  0.551270
# 996 -0.387320  0.165030  1.010020
# 997 -0.100322  0.058141  0.303219
# 998 -0.066833  0.079562  0.167289
# 999 -0.264869  0.252244  0.531544
#
# [1000 rows x 54 columns]

# %% [markdown]
# ### Preparing data for Training ##

# %%
Norm=Norm.drop(['Reviews','clean_text','Tweet_length'],axis=1) # normalized
Not_Norm=Not_Norm.drop(['Reviews','clean_text','Tweet_length'],axis=1) #not-normalized

# %% [markdown]
# ### Y-Label ###

# %%
Y_Norm = df['sentiments']
Y_Not_Norm = df['sentiments']

# %%
Norm=Norm.drop(['sentiments'],axis=1)
Not_Norm=Not_Norm.drop(['sentiments'],axis=1)

# %% [markdown]
# ### Training using different kinds of Algorithm and Testing (by finding accuracy score and f1_score)  ###

# %%
X_Train_Not_Norm,X_Test_Not_Norm,Y_Train_Not_Norm,Y_Test_Not_Norm=train_test_split(Not_Norm,Y_Not_Norm,test_size=0.2,
                                                                                   random_state=1) # not-normalized

# %%
X_Train_Norm,X_Test_Norm,Y_Train_Norm,Y_Test_Norm=train_test_split(Norm,Y_Norm,test_size=0.2,
                                                                                   random_state=1) # normalized

# %% [markdown]
# ## Not-Normalized ##

# %% [markdown]
# ## Logistic Regression ##

# %%
lg = LogisticRegression()
lg.fit(X_Train_Not_Norm,Y_Train_Not_Norm)
predict = lg.predict(X_Test_Not_Norm)
print("Accuracy : {:.2f} %".format(accuracy_score(Pred,Y_Test_Not_Norm)*100))
print("F1-Score : {:.2f} ".format(f1_score(Pred,Y_Test_Not_Norm)))
# Out:
# Accuracy : 57.50 %
# F1-Score : 0.42

# %% [markdown]
# ## Hyperparameter tuning ##

# %%
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000] }
clf = GridSearchCV(LogisticRegression(penalty='l2'), param_grid)
clf.fit(X_Train_Not_Norm, Y_Train_Not_Norm)
clf.best_estimator_.C
# Out:
# 1000

# %% [markdown]
# after tuning  C is found to be 1000 as best estimator

# %%
lg = LogisticRegression(C=1000)
lg.fit(X_Train_Not_Norm,Y_Train_Not_Norm)
predict = lg.predict(X_Test_Not_Norm)
print("Accuracy : {:.2f} %".format(accuracy_score(predict,Y_Test_Not_Norm)*100))
print("F1-Score : {:.2f} ".format(f1_score(predict,Y_Test_Not_Norm)))
f1 = accuracy_score(predict,Y_Test_Not_Norm)
# Out:
# Accuracy : 61.50 %
# F1-Score : 0.57

# %% [markdown]
#  both accurcy score and f1_score increases
# ## Naive Bayes ##

# %%
Nb=GaussianNB()
Nb.fit(X_Train_Not_Norm,Y_Train_Not_Norm)
Pred=Nb.predict(X_Test_Not_Norm)
print("Accuracy : {:.2f} %".format(accuracy_score(Pred,Y_Test_Not_Norm)*100))
print("F1-Score : {:.2f} ".format(f1_score(Pred,Y_Test_Not_Norm)))
f2=accuracy_score(Pred,Y_Test_Not_Norm)
# Out:
# Accuracy : 57.50 %
# F1-Score : 0.42

# %% [markdown]
# since accuracy_score is less than logistic regression,we won't consider it

# %% [markdown]
# ## SVM ##

# %%
sv = SVC()
sv.fit(X_Train_Not_Norm,Y_Train_Not_Norm)
pred = sv.predict(X_Test_Not_Norm)
print("Accuracy : {:.2f} %".format(accuracy_score(pred,Y_Test_Not_Norm)*100))
print("F1-Score : {:.2f} ".format(f1_score(pred,Y_Test_Not_Norm)))
# Out:
# Accuracy : 55.50 %
# F1-Score : 0.44

# %% [markdown]
# accuracy is very low so we won't work on it.

# %% [markdown]
# ## Random Forest ##

# %%
Rfc=RandomForestClassifier(random_state=12)
Rfc.fit(X_Train_Not_Norm,Y_Train_Not_Norm)
Pred=Rfc.predict(X_Test_Not_Norm)
print("Accuracy : {:.2f} %".format(accuracy_score(Pred,Y_Test_Not_Norm)*100))
print("F1-Score : {:.2f} ".format(f1_score(Pred,Y_Test_Not_Norm)))
# Out:
# Accuracy : 59.50 %
# F1-Score : 0.54

# %% [markdown]
# ## Hyperparameter tuning##

# %%
rf_params = { 
    'n_estimators': [200, 700],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth':np.arange(5,15,1)
}

gs_random = GridSearchCV(estimator=rf, param_grid=rf_params, cv= 5)
gs_random.fit(X_Train_Not_Norm, Y_Train_Not_Norm)
print (gs_random.best_params_)
# Out:
# {'max_depth': 11, 'max_features': 'auto', 'n_estimators': 200}

# %% [markdown]
# best parameters are fetched after tuning

# %%
Rfc=RandomForestClassifier(random_state=100,max_depth= 11, max_features='auto', n_estimators= 200)
Rfc.fit(X_Train_Not_Norm,Y_Train_Not_Norm)
Pred=Rfc.predict(X_Test_Not_Norm)
print("Accuracy : {:.2f} %".format(accuracy_score(Pred,Y_Test_Not_Norm)*100))
print("F1-Score : {:.2f} ".format(f1_score(Pred,Y_Test_Not_Norm)))
f4 = accuracy_score(Pred,Y_Test_Not_Norm)
# Out:
# Accuracy : 63.00 %
# F1-Score : 0.61

# %% [markdown]
# both accurcy score and f1_score increases and score jumps to 63%

# %% [markdown]
# ## Normalized ##

# %% [markdown]
# ## Logistic Regression##

# %%
LG = LogisticRegression()
LG.fit(X_Train_Norm,Y_Train_Norm)
PredicT = LG.predict(X_Test_Norm)
print("Accuracy : {:.2f} %".format(accuracy_score(PredicT,Y_Test_Norm)*100))
print("F1-Score : {:.2f} ".format(f1_score(PredicT,Y_Test_Norm)))
# Out:
# Accuracy : 58.50 %
# F1-Score : 0.55

# %% [markdown]
# ## Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000] }
clf = GridSearchCV(LogisticRegression(penalty='l2'), param_grid)
clf.fit(X_Train_Norm, Y_Train_Norm)
clf.best_estimator_.C
# Out:
# 1000

# %% [markdown]
# C hyperparameter is found after Tuning

# %%
LG1 = LogisticRegression(C=1000)
LG1.fit(X_Train_Norm,Y_Train_Norm)
PrediCT = LG1.predict(X_Test_Norm)
print("Accuracy : {:.2f} %".format(accuracy_score(PrediCT,Y_Test_Norm)*100))
print("F1-Score : {:.2f} ".format(f1_score(PrediCT,Y_Test_Norm)))
F1=accuracy_score(PrediCT,Y_Test_Norm)
# Out:
# Accuracy : 61.50 %
# F1-Score : 0.57

# %% [markdown]
# both accuracy score and f1_score increases to a good level

# %% [markdown]
# ## Naive-Bayes

# %%
NB=GaussianNB()
NB.fit(X_Train_Norm,Y_Train_Norm)
PRED=NB.predict(X_Test_Norm)
print("Accuracy : {:.2f} %".format(accuracy_score(Pred,Y_Test_Norm)*100))
print("F1-Score : {:.2f} ".format(f1_score(PRED,Y_Test_Norm)))
F2 = accuracy_score(Pred,Y_Test_Norm)
# Out:
# Accuracy : 63.00 %
# F1-Score : 0.42

# %% [markdown]
# accuracy is low than logistic regression so we won't consider it.

# %% [markdown]
# ## SVM

# %%
SV = SVC()
SV.fit(X_Train_Norm,Y_Train_Norm)
PRed = SV.predict(X_Test_Norm)
print("Accuracy : {:.2f} %".format(accuracy_score(PRed,Y_Test_Norm)*100))
print("F1-Score : {:.2f} ".format(f1_score(PRed,Y_Test_Norm)))
# Out:
# Accuracy : 55.50 %
# F1-Score : 0.44

# %% [markdown]
# Accuracy is not upto the mark

# %% [markdown]
# ## Random Forest##

# %%
Rf = RandomForestClassifier(random_state=200)
Rf.fit(X_Train_Norm,Y_Train_Norm)
PREdict = Rf.predict(X_Test_Norm)
print("Accuracy : {:.2f} %".format(accuracy_score(PREdict,Y_Test_Norm)*100))
print("F1-Score : {:.2f} ".format(f1_score(PREdict,Y_Test_Norm)))
# Out:
# Accuracy : 54.00 %
# F1-Score : 0.47

# %% [markdown]
# ## Hyperparameter tuning

# %%
rf_params = { 
    'n_estimators': [200, 700],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth':np.arange(5,15,1)
}

gs_random = GridSearchCV(estimator=Rf, param_grid=rf_params, cv= 5)
gs_random.fit(X_Train_Norm, Y_Train_Norm)
print (gs_random.best_params_)
# Out:
# {'max_depth': 8, 'max_features': 'log2', 'n_estimators': 200}

# %% [markdown]
# best parameters are selected after Tuning.

# %%
Rf1 = RandomForestClassifier(random_state=100,max_depth= 8, max_features= 'log2', n_estimators= 200)
Rf1.fit(X_Train_Norm,Y_Train_Norm)
PREDict = Rf1.predict(X_Test_Norm)
print("Accuracy : {:.2f} %".format(accuracy_score(PREDict,Y_Test_Norm)*100))
print("F1-Score : {:.2f} ".format(f1_score(PREDict,Y_Test_Norm)))
F4 = accuracy_score(PREDict,Y_Test_Norm)
# Out:
# Accuracy : 62.50 %
# F1-Score : 0.59

# %% [markdown]
# there is an increase in accuracy score and f1-score with good output

# %% [markdown]
# # OBSERVATIONS #

# %% [markdown]
# ##  For Not-Normalized data

# %%
Accuracy = [f1,f2,f3,f4]

Algo = ['LogisticRegression','GaussianNB','SVM(rbf)','Random Forest']

# %%
sns.barplot(y=Accuracy,x=Algo,data=df)

# %% [markdown]
# Random-forest has highest accuracy_score

# %% [markdown]
# ## for Normalized data

# %%
Accuracy = [F1,F2,F3,F4]

Algo = ['LogisticRegression','GaussianNB','SVM(rbf)','Random Forest']

# %%
sns.barplot(x=Algo,y=Accuracy)

# %% [markdown]
# Random_forest has highest accuracy_score
# ### Conclusion

# %% [markdown]
# * Random Forest has highest accuracy than any other model for both the cases(Normalized and Not-Normalized datasets).
# * Got 63% accuracy for not-normalized data using random-forest technique<br>
# * This model can analyse any reviews' sentiments nearly upto 60% correctness which is an average performance of the model.<br>
# * After performing Hyperparameter-tuning accuracy_score and f1_score increases<br>
# * All the 4 models differ very slightly.<br>
# * Logistic Regression and Random-Forest modelling techniques performs the best after Tuning(Thus tuning is very necessary :)). <br>
# * Tuning is done to avoid overfitting and underfitting of the data and for removing some kind of noises.<br>
# * Since collected data is not skewed much (i.e. both positive and negative reviews are equal in amount)<br>
#  Model performance is affected.
